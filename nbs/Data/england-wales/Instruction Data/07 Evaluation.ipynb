# %%
import json
import sys
import yaml
import re
# List of entity types we want to evaluate
ENTITY_TYPES = [
    "citation",
    "judges",
    "ConvCourtName",
    "ConvictPleaDate",
    "ConvictOffence",
    "AcquitOffence",
    "ConfessPleadGuilty",  # Adjusted entity name to match YAML sample
    "PleaPoint",
    "RemandDecision",
    "RemandCustodyTime",
    "SentCourtName",
    "SentenceReceived",
    "SentenceServed",
    "WhatAncilliary",
    "OffSex",
    "OffAgeOffence",
    "OffJobOffence",
    "OffHomeOffence",
    "OffMentalOffence",
    "OffIntoxOffence",
    "OffVicRelation",
    "VictimType",
    "VicNum",
    "VicSex",
    "VicAgeOffence",
    "VicJobOffence",
    "VicHomeOffence",
    "VicMentalOffence",
    "VicIntoxOffence",
    "ProsEvidTypeTrial",
    "DefEvidTypeTrial",
    "PreSentReport",
    "AggFactSent",
    "MitFactSent",
    "VicImpactStatement",
    "Appellant",
    "CoDefAccNum",
    "AppealAgainst",
    "AppealGround",
    "SentGuideWhich",
    "AppealOutcome",
    "ReasonQuashConv",
    "ReasonSentExcessNotLenient",
    "ReasonSentLenientNotExcess",
    "ReasonDismiss",
]

def is_empty(val):
    """Determine if a value is effectively empty or non-informative."""
    if val is None:
        return True
    if isinstance(val, str):
        cleaned = val.strip().lower()
        if cleaned in ["", "nan", "null", "-"]:
            return True
    return False

def compute_metrics_from_counts(tp, fp, fn):
    """Compute precision, recall, and F1 given counts of TP, FP, FN."""
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    return precision, recall, f1


import re

def parse_custom_text(input_text):
    """
    Parse text into structured data, handling variations and edge cases.
    """
    # Split into sections using `\n` as a logical delimiter
    sections = input_text.split("\n")
    structured_data = []
    current_section = {}
    current_key = None

    # Patterns to identify section headers, Comment, and Exact fields
    section_pattern = re.compile(r"^(\w+):$")
    comment_pattern = re.compile(r"^\s*Comment:\s*(.*)$")
    exact_pattern = re.compile(r"^\s*Exact:\s*(.*)$")

    for line in sections:
        # Match section header (e.g., `citation:`)
        section_match = section_pattern.match(line.strip())
        if section_match:
            # Save the current section if it exists
            if current_section:
                structured_data.append(current_section)
                current_section = {}
            # Start a new section
            current_key = section_match.group(1)
            current_section["section"] = current_key
            continue

        # Match Comment field
        comment_match = comment_pattern.match(line.strip())
        if comment_match:
            comment_value = comment_match.group(1).strip("'").strip('"') or "nan"
            current_section["Comment"] = comment_value
            continue

        # Match Exact field
        exact_match = exact_pattern.match(line.strip())
        if exact_match:
            exact_value = exact_match.group(1).strip("'").strip('"') or "nan"
            current_section["Exact"] = exact_value
            continue

    # Append the last section if it exists
    if current_section:
        structured_data.append(current_section)

    return structured_data

# %%
entity_stats = { entity: {"TP": 0, "FP": 0, "FN": 0} for entity in ENTITY_TYPES }

total_tp = total_fp = total_fn = 0


json_file_path='/home/stirunag/Downloads/sft_on_english_data/sft_on_english_data/predictions/llama_3.1_8b_instruct_fine_tuned_appealcourt_coded/outputs_42.json'


with open(json_file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 125

# %%
answer_text = data[10].get("answer", "")
gold_text = data[10].get("gold", "")

[answer_text, gold_text]
# Out:
# ['```yaml\ncitation:\n  Comment: \'[2023] EWCA Crim 1252\'\n  Exact: \'IN THE COURT OF APPEAL CRIMINAL DIVISION [2023] EWCA Crim 1252 No. 202300471 A4 Royal Courts of Justice Wednesday, 11 October 2023\'\n\njudges:\n  Comment: \'LORD JUSTICE WARBY, MR JUSTICE MURRAY, HIS HONOUR JUDGE LEONARD KC\'\n  Exact: \'Before: LORD JUSTICE WARBY MR JUSTICE MURRAY HIS HONOUR JUDGE LEONARD KC\'\n\nConvCourtName:\n  Comment: \'Crown Court at Leeds\'\n  Exact: \'On 30 January 2023, in the Crown Court at Leeds\'\n\nConvictPleaDate:\n  Comment: \'2023-01-30\'\n  Exact: \'On 30 January 2023\'\n\nConvictOffence:\n  Comment: \'Participation in a conspiracy to supply a class A drug, supplying a class A drug, dangerous driving, perverting the course of justice\'\n  Exact: \'The offences we have mentioned were the subject of three indictments. On the first indictment  (case T20217672), the appellant faced a single count of participation in a conspiracy to supply a class A drug between 1 May and 1 October 2020.  The operation centred on drug dealing to a number of flats and apartments in a private block of flats at Armley.  It employed two dealing lines. Customers would place orders by calling whichever line was active at the time.  The holder of the phone would then attend and supply the drugs.\'\n\nAcquitOffence:\n  Comment: \'null\'\n  Exact: \'\'\n\nConfessPleadGuilty:\n  Comment: \'Yes\'\n  Exact: \'He pleaded guilty to the second drug offence at the plea and trial preparation hearing for that offence. Shortly afterwards he entered a guilty plea to the first indictment also.\'\n\nPleaPoint:\n  Comment: \'plea and trial preparation hearing, first indictment\'\n  Exact: \'He pleaded guilty to the second drug offence at the plea and trial preparation hearing for that offence. Shortly afterwards he entered a guilty plea to the first indictment also.\'\n\nRemandDecision:\n  Comment: \'Don’t know\'\n  Exact: \'\'\n\nRemandCustodyTime:\n  Comment: \'nan\'\n  Exact: \'\'\n\nSentCourtName:\n  Comment: \'Crown Court at Leeds\'\n  Exact: \'On 30 January 2023, in the Crown Court at Leeds\'\n\nSentenceReceived:\n  Comment: \'7 years and 4 months imprisonment, 68 months driving disqualification\'\n  Exact: \'He was sentenced to a total of seven years and four months\\\' imprisonment, having earlier pleaded guilty to two drug offences, one of dangerous driving and one of perverting the course of justice.  He was disqualified from driving for 68 months.\'\n\nSentenceServed:\n  Comment: \'Consecutive\'\n  Exact: \'Having regard to the fact that you had been charged in respect of the drugs offences at this point those sentences are consecutive\'\n\nWhatAncilliary:\n  Comment: \'Restraining orders, Compensation orders\'\n  Exact: \'There was also a letter from the appellant explaining how he came to offend, and expressing his remorse.\'\n\nOffSex:\n  Comment: \'Male\'\n  Exact: \'The appellant was aged 40 at the date of sentence.\'\n\nOffAgeOffence:\n  Comment: \'40\'\n  Exact: \'The appellant was aged 40 at the date of sentence.\'\n\nOffJobOffence:\n  Comment: \'Scaffolder\'\n  Exact: \'He had lost his job as a scaffolder and  had family issues.\'\n\nOffHomeOffence:\n  Comment: \'Don’t know\'\n  Exact: \'\'\n\nOffMentalOffence:\n  Comment: \'Had mental health problems\'\n  Exact: \'He had accumulated a drugs debt, which resulted in others subjecting him to mental pressure and threats.\'\n\nOffIntoxOffence:\n  Comment: \'Yes-drinking\'\n  Exact: \'He had turned to drink and drugs in 2020 when the pandemic forced his employer out of business\'\n\nOffVicRelation:\n  Comment: \'Stranger\'\n  Exact: \'The officer asked a female unknown to him where he could buy "rock" or "white".\'\n\nVictimType:\n  Comment: \'Individual person\'\n  Exact: \'The officer asked a female unknown to him where he could buy "rock" or "white".\'\n\nVicNum:\n  Comment: \'1\'\n  Exact: \'The officer asked a female unknown to him where he could buy "rock" or "white".\'\n\nVicSex:\n  Comment: \' ...
#  "citation:\n  Comment: nan\n  Exact: [2023] EWCA Crim 1252\njudges:\n  Comment: nan\n  Exact: ['LORD JUSTICE WARBY', 'MR JUSTICE MURRAY', 'HIS HONOUR JUDGE LEONARD KC']\n\n  ConvCourtName:\n    Comment: nan\n    Exact: Crown Court at Leeds\n  ConvictPleaDate:\n    Comment: nan\n    Exact: 30 January 2023\n  ConvictOffence:\n    Comment: nan\n    Exact: supplying a class A drug\n  AcquitOffence:\n    Comment: nan\n    Exact: nan\n  Confess/Plead :\n    Comment: nan\n    Exact: nan\n  PleaPoint:\n    Comment: nan\n    Exact: at the plea and trial preparation hearing\n  RemandDecision:\n    Comment: nan\n    Exact: on remand\n  RemandCustodyTime:\n    Comment: nan\n    Exact: Don't know\n  SentCourtName:\n    Comment: nan\n    Exact: Crown Court at Leeds\n  Sentence:\n    Comment: nan\n    Exact: seven years and four months' imprisonment\n  SentServe:\n    Comment: nan\n    Exact: consecutive\n  WhatAncilliary:\n    Comment: nan\n    Exact: nan\n  OffSex:\n    Comment: Male\n    Exact: He\n  OffAgeOffence:\n    Comment: nan\n    Exact: Don't know\n  OffJobOffence:\n    Comment: nan\n    Exact: Don't know\n  OffHomeOffence:\n    Comment: nan\n    Exact: Don't know\n  OffMentalOffence:\n    Comment: Mental health problems\n    Exact: addiction\n  OffIntoxOffence:\n    Comment: nan\n    Exact: Don't know\n  OffVicRelation:\n    Comment: nan\n    Exact: nan\n  VictimType:\n    Comment: nan\n    Exact: nan\n  VicNum:\n    Comment: nan\n    Exact: nan\n  VicSex:\n    Comment: nan\n    Exact: nan\n  VicAgeOffence:\n    Comment: nan\n    Exact: nan\n  VicJobOffence:\n    Comment: nan\n    Exact: nan\n  VicHomeOffence:\n    Comment: nan\n    Exact: nan\n  VicMentalOffence:\n    Comment: nan\n    Exact: nan\n  VicIntoxOffence:\n    Comment: nan\n    Exact: nan\n  ProsEvidTypeTrial:\n    Comment: nan\n    Exact: Expert evidence\n  DefEvidTypeTrial:\n    Comment: nan\n    Exact: nan\n  PreSentReport:\n    Comment: nan\n    Exact: Don't know\n  AggFactSent:\n    Comment: nan\n    Exact: previous convictions\n  MitFactSent:\n    Comment: nan\n    Exact: remorse\n  VicImpactStatement:\n    Comment: nan\n    Exact: Don't know\n  Appellant:\n    Comment: Offender\n    Exact: Appellant\n  CoDefAccNum:\n    Comment: nan\n    Exact: Don't know\n  AppealAgainst:\n    Comment: nan\n    Exact: appeals against sentence\n  AppealGround:\n    Comment: nan\n    Exact: he failed at this stage to have sufficient regard to the principle of totality\n  SentGuideWhich:\n    Comment: nan\n    Exact: section 35A of the Road Traffic Offenders Act 1988\n  AppealOutcome:\n    Comment: nan\n    Exact: consequential adjustment to the length of the driving disqualification.  This must be reduced, we calculate, to one of 65 months, comprising 24 months' disqualification with an uplift of four months\n  ReasonQuashConv:\n    Comment: nan\n    Exact: nan\n  ReasonSentExcessNotLenient:\n    Comment: nan\n    Exact: In our judgment, this balance called for a  significant downward adjustment before reduction for guilty plea.\n  ReasonSentLenientNotExcess:\n    Comment: nan\n    Exact: nan\n  ReasonDismiss:\n    Comment: nan\n    Exact: nan\n"]

# %%
answer_parsed = parse_custom_text(answer_text) 
answer_parsed
# Out:
# [{'section': 'citation',
#   'Comment': '[2023] EWCA Crim 1252',
#   'Exact': 'IN THE COURT OF APPEAL CRIMINAL DIVISION [2023] EWCA Crim 1252 No. 202300471 A4 Royal Courts of Justice Wednesday, 11 October 2023'},
#  {'section': 'judges',
#   'Comment': 'LORD JUSTICE WARBY, MR JUSTICE MURRAY, HIS HONOUR JUDGE LEONARD KC',
#   'Exact': 'Before: LORD JUSTICE WARBY MR JUSTICE MURRAY HIS HONOUR JUDGE LEONARD KC'},
#  {'section': 'ConvCourtName',
#   'Comment': 'Crown Court at Leeds',
#   'Exact': 'On 30 January 2023, in the Crown Court at Leeds'},
#  {'section': 'ConvictPleaDate',
#   'Comment': '2023-01-30',
#   'Exact': 'On 30 January 2023'},
#  {'section': 'ConvictOffence',
#   'Comment': 'Participation in a conspiracy to supply a class A drug, supplying a class A drug, dangerous driving, perverting the course of justice',
#   'Exact': 'The offences we have mentioned were the subject of three indictments. On the first indictment  (case T20217672), the appellant faced a single count of participation in a conspiracy to supply a class A drug between 1 May and 1 October 2020.  The operation centred on drug dealing to a number of flats and apartments in a private block of flats at Armley.  It employed two dealing lines. Customers would place orders by calling whichever line was active at the time.  The holder of the phone would then attend and supply the drugs.'},
#  {'section': 'AcquitOffence', 'Comment': 'null', 'Exact': 'nan'},
#  {'section': 'ConfessPleadGuilty',
#   'Comment': 'Yes',
#   'Exact': 'He pleaded guilty to the second drug offence at the plea and trial preparation hearing for that offence. Shortly afterwards he entered a guilty plea to the first indictment also.'},
#  {'section': 'PleaPoint',
#   'Comment': 'plea and trial preparation hearing, first indictment',
#   'Exact': 'He pleaded guilty to the second drug offence at the plea and trial preparation hearing for that offence. Shortly afterwards he entered a guilty plea to the first indictment also.'},
#  {'section': 'RemandDecision', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'RemandCustodyTime', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'SentCourtName',
#   'Comment': 'Crown Court at Leeds',
#   'Exact': 'On 30 January 2023, in the Crown Court at Leeds'},
#  {'section': 'SentenceReceived',
#   'Comment': '7 years and 4 months imprisonment, 68 months driving disqualification',
#   'Exact': "He was sentenced to a total of seven years and four months\\' imprisonment, having earlier pleaded guilty to two drug offences, one of dangerous driving and one of perverting the course of justice.  He was disqualified from driving for 68 months."},
#  {'section': 'SentenceServed',
#   'Comment': 'Consecutive',
#   'Exact': 'Having regard to the fact that you had been charged in respect of the drugs offences at this point those sentences are consecutive'},
#  {'section': 'WhatAncilliary',
#   'Comment': 'Restraining orders, Compensation orders',
#   'Exact': 'There was also a letter from the appellant explaining how he came to offend, and expressing his remorse.'},
#  {'section': 'OffSex',
#   'Comment': 'Male',
#   'Exact': 'The appellant was aged 40 at the date of sentence.'},
#  {'section': 'OffAgeOffence',
#   'Comment': '40',
#   'Exact': 'The appellant was aged 40 at the date of sentence.'},
#  {'section': 'OffJobOffence',
#   'Comment': 'Scaffolder',
#   'Exact': 'He had lost his job as a scaffolder and  had family issues.'},
#  {'section': 'OffHomeOffence', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'OffMentalOffence',
#   'Comment': 'Had mental health problems',
#   'Exact': 'He had accumulated a drugs debt, which resulted in others subjecting him to mental pressure and threats.'},
#  {'section': 'OffIntoxOffence',
#   'Comment': 'Yes-drinking',
#   'Exact': 'He had turned to drink and drugs in 2020 when the pandemic forced his employer out of business'},
#  {'section': 'OffVicRelation',
#   'Comment': 'Stranger',
#   'Exact': 'The officer asked a female unknown to him where he could buy "rock" or "white".'},
#  {'section': 'VictimType',
#   'Comment': 'Individual person',
#   'Exact': 'The officer asked a female unknown to him where he could buy "rock" or "white".'},
#  {'section': 'VicNum',
#   'Comment': '1',
#   'Exact': 'The officer asked a female unknown to him where he could buy "rock" or "white".'},
#  {'section': 'VicSex',
#   'Comment': 'Female',
#   'Exact': 'The officer asked a female unknown to him where he could buy "rock" or "white".'},
#  {'section': 'VicAgeOffence', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'VicJobOffence', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'VicHomeOffence', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'VicMentalOffence', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'VicIntoxOffence', 'Comment': 'No', 'Exact': 'nan'},
#  {'section': 'ProsEvidTypeTrial',
#   'Comment': 'CCTV, DNA match, Eye-witness testimony',
#   'Exact': 'The evidence showed that the conspirators were dealing both heroin and cocaine.  The dealer lines had received over 57,000 messages during the conspiracy period.'},
#  {'section': 'DefEvidTypeTrial',
#   'Comment': 'Offender denies offence, Lack of DNA evidence',
#   'Exact': 'In interview, the appellant made no comment.'},
#  {'section': 'PreSentReport',
#   'Comment': 'Don’t know',
#   'Exact': 'There was no pre-sentence report, and we are satisfied that none was required.'},
#  {'section': 'AggFactSent',
#   'Comment': 'Offence committed while on bail',
#   'Exact': 'The charge of perverting the course of justice arose from what happened the following day.  The appellant called West Yorkshire Police and made a false report that his car had been stolen.'},
#  {'section': 'MitFactSent',
#   'Comment': 'Offender showed genuine remorse',
#   'Exact': 'He had accumulated a drugs debt, which resulted in others subjecting him to mental pressure and threats.  He was asked to, and he did, commit the offence on the second indictment in order to clear the outstanding amount.'},
#  {'section': 'VicImpactStatement', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'Appellant',
#   'Comment': 'Offender',
#   'Exact': 'The appellant appeals against sentence with the leave of the single judge.'},
#  {'section': 'CoDefAccNum',
#   'Comment': '3',
#   'Exact': 'The operation centred on drug dealing to a number of flats and apartments in a private block of flats at Armley.  It employed two dealing lines. Customers would place orders by calling whichever line was active at the time.  The holder of the phone would then attend and supply the drugs.'},
#  {'section': 'AppealAgainst',
#   'Comment': 'Sentence is unduly excessive',
#   'Exact': 'The defence pointed out that the prosecution assertion in respect of the second indictment, that the appellant had hired a vehicle, was contrary to the evidence, which showed that someone else had done so.'},
#  {'section': 'AppealGround',
#   'Comment': 'Trial judge admitted prejudicial evidence',
#   'Exact': 'The defence pointed out that the prosecution assertion in respect of the second indictment, that the appellant had hired a vehicle, was contrary to the evidence, which showed that someone else had done so.'},
#  {'section': 'SentGuideWhich',
#   'Comment': 'Road Traffic Offenders Act 1988',
#   'Exact': "This must be reduced, we calculate, to one of 65 months, comprising 24 months\\' disqualification with an uplift of four months in respect of the dangerous driving (pursuant to section 35A of the Road Traffic Offenders Act 1988) and a further uplift of 37 months in respect of the other offences under section 35B of the 1988 Act."},
#  {'section': 'AppealOutcome',
#   'Comment': 'Partially allowed',
#   'Exact': 'To that extent, the appeal is allowed.'},
#  {'section': 'ReasonQuashConv', 'Comment': 'Don’t know', 'Exact': 'nan'},
#  {'section': 'ReasonSentExcessNotLenient',
#   'Comment': 'Offence committed while on bail',
#   'Exact': 'The charge of perverting the course of justice arose from what happened the following day.  The appellant called West Yorkshire Police and made a false report that his car had been stolen.'},
#  {'section': 'ReasonSentLenientNotExcess',
#   'Comment': 'Don’t know',
#   'Exact': 'nan'},
#  {'section': 'ReasonDismiss', 'Comment': 'Don’t know', 'Exact': 'nan'}]

# %%
gold_parsed = parse_custom_text(gold_text)
gold_parsed
# Out:
# [{'section': 'citation', 'Comment': 'nan', 'Exact': '[2023] EWCA Crim 1252'},
#  {'section': 'judges',
#   'Comment': 'nan',
#   'Exact': "['LORD JUSTICE WARBY', 'MR JUSTICE MURRAY', 'HIS HONOUR JUDGE LEONARD KC']"},
#  {'section': 'ConvCourtName',
#   'Comment': 'nan',
#   'Exact': 'Crown Court at Leeds'},
#  {'section': 'ConvictPleaDate', 'Comment': 'nan', 'Exact': '30 January 2023'},
#  {'section': 'ConvictOffence',
#   'Comment': 'nan',
#   'Exact': 'supplying a class A drug'},
#  {'section': 'AcquitOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'PleaPoint',
#   'Comment': 'nan',
#   'Exact': 'at the plea and trial preparation hearing'},
#  {'section': 'RemandDecision', 'Comment': 'nan', 'Exact': 'on remand'},
#  {'section': 'RemandCustodyTime', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'SentCourtName',
#   'Comment': 'nan',
#   'Exact': 'Crown Court at Leeds'},
#  {'section': 'Sentence',
#   'Comment': 'nan',
#   'Exact': "seven years and four months' imprisonment"},
#  {'section': 'SentServe', 'Comment': 'nan', 'Exact': 'consecutive'},
#  {'section': 'WhatAncilliary', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'OffSex', 'Comment': 'Male', 'Exact': 'He'},
#  {'section': 'OffAgeOffence', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'OffJobOffence', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'OffHomeOffence', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'OffMentalOffence',
#   'Comment': 'Mental health problems',
#   'Exact': 'addiction'},
#  {'section': 'OffIntoxOffence', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'OffVicRelation', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VictimType', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicNum', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicSex', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicAgeOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicJobOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicHomeOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicMentalOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'VicIntoxOffence', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'ProsEvidTypeTrial',
#   'Comment': 'nan',
#   'Exact': 'Expert evidence'},
#  {'section': 'DefEvidTypeTrial', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'PreSentReport', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'AggFactSent', 'Comment': 'nan', 'Exact': 'previous convictions'},
#  {'section': 'MitFactSent', 'Comment': 'nan', 'Exact': 'remorse'},
#  {'section': 'VicImpactStatement', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'Appellant', 'Comment': 'Offender', 'Exact': 'Appellant'},
#  {'section': 'CoDefAccNum', 'Comment': 'nan', 'Exact': "Don't know"},
#  {'section': 'AppealAgainst',
#   'Comment': 'nan',
#   'Exact': 'appeals against sentence'},
#  {'section': 'AppealGround',
#   'Comment': 'nan',
#   'Exact': 'he failed at this stage to have sufficient regard to the principle of totality'},
#  {'section': 'SentGuideWhich',
#   'Comment': 'nan',
#   'Exact': 'section 35A of the Road Traffic Offenders Act 1988'},
#  {'section': 'AppealOutcome',
#   'Comment': 'nan',
#   'Exact': "consequential adjustment to the length of the driving disqualification.  This must be reduced, we calculate, to one of 65 months, comprising 24 months' disqualification with an uplift of four months"},
#  {'section': 'ReasonQuashConv', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'ReasonSentExcessNotLenient',
#   'Comment': 'nan',
#   'Exact': 'In our judgment, this balance called for a  significant downward adjustment before reduction for guilty plea.'},
#  {'section': 'ReasonSentLenientNotExcess', 'Comment': 'nan', 'Exact': 'nan'},
#  {'section': 'ReasonDismiss', 'Comment': 'nan', 'Exact': 'nan'}]

# %%
from difflib import SequenceMatcher

def similarity(a, b):
    """Compute similarity ratio between two strings."""
    return SequenceMatcher(None, a, b).ratio()

SIMILARITY_THRESHOLD = 0.5  # Adjust based on acceptable similarity level

# Process each record
for record in data:
    answer_text = record.get("answer", "")
    gold_text = record.get("gold", "")

    # Parse the structured text from answer and gold fields
    try:
        answer_parsed = parse_custom_text(answer_text) or []
    except Exception as e:
        print(f"Error parsing answer text: {e}")
        answer_parsed = []
    try:
        gold_parsed = parse_custom_text(gold_text) or []
    except Exception as e:
        print(f"Error parsing gold text: {e}")
        gold_parsed = []

    # Convert parsed lists into dictionaries for easier lookup
    answer_dict = {entry["section"]: entry for entry in answer_parsed}
    gold_dict = {entry["section"]: entry for entry in gold_parsed}

    for entity in ENTITY_TYPES:
        # Extract "Comment" and "Exact" values
        gold_entity = gold_dict.get(entity, {})
        pred_entity = answer_dict.get(entity, {})
    
        gold_comment = gold_entity.get("Comment", "nan")
        pred_comment = pred_entity.get("Comment", "nan")
    
        gold_exact = gold_entity.get("Exact", "nan")
        pred_exact = pred_entity.get("Exact", "nan")
    
        # Initialize stats for the entity
        if entity not in entity_stats:
            entity_stats[entity] = {"TP": 0, "FP": 0, "FN": 0}
    
        # Function to update TP, FP, FN based on match
        def update_metrics(gold, pred):
            gold_present = not is_empty(gold)
            pred_present = not is_empty(pred)
            if gold_present:
                if pred_present:
                    # Check for similarity
                    if similarity(str(gold).strip(), str(pred).strip()) >= SIMILARITY_THRESHOLD:
                        entity_stats[entity]["TP"] += 1
                        return 1, 0, 0  # TP
                    else:
                        # Similarity below threshold
                        return 0, 1, 1  # FP, FN
                else:
                    # Gold present but prediction missing
                    return 0, 0, 1  # FN
            else:
                if pred_present:
                    # Prediction made but nothing in gold
                    return 0, 1, 0  # FP
                # Neither present: do nothing
                return 0, 0, 0
    
        # Update metrics for "Comment"
        tp, fp, fn = update_metrics(gold_comment, pred_comment)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
        # Update metrics for "Exact"
        tp, fp, fn = update_metrics(gold_exact, pred_exact)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn

# Compute overall micro-averaged metrics
overall_precision, overall_recall, overall_f1 = compute_metrics_from_counts(total_tp, total_fp, total_fn)
print("\nOverall (Micro-Averaged) Metrics:")
print(f"Precision = {overall_precision:.3f}")
print(f"Recall    = {overall_recall:.3f}")
print(f"F1        = {overall_f1:.3f}")
# Out:
# Overall (Micro-Averaged) Metrics:
# Precision = 0.109
# Recall    = 0.199
# F1        = 0.141

# %%
import pandas as pd

# Prepare data structure for storing results per citation
results = {}

# Process each record in data
for record in data:
    answer_text = record.get("answer", "")
    gold_text = record.get("gold", "")

    # Parse structured content from answer and gold fields
    try:
        answer_parsed = parse_custom_text(answer_text) or []
    except Exception as e:
        print(f"Error parsing answer text: {e}")
        answer_parsed = []

    try:
        gold_parsed = parse_custom_text(gold_text) or []
    except Exception as e:
        print(f"Error parsing gold text: {e}")
        gold_parsed = []

    # Convert parsed lists to dictionaries for easier lookup
    answer_dict = {entry["section"]: entry for entry in answer_parsed}
    gold_dict = {entry["section"]: entry for entry in gold_parsed}

    # Extract citation for column grouping
    citation_entity = gold_dict.get("citation", {})
    citation_number = citation_entity.get("Exact", "Unknown Citation")

    if citation_number not in results:
        results[citation_number] = []

    for entity in ENTITY_TYPES:
        # Extract gold and predicted values for exact and comment
        gold_entity = gold_dict.get(entity, {})
        pred_entity = answer_dict.get(entity, {})

        gold_exact = gold_entity.get("Exact", "nan")
        gold_comment = gold_entity.get("Comment", "nan")
        pred_exact = pred_entity.get("Exact", "nan")
        pred_comment = pred_entity.get("Comment", "nan")

        # Combine exact and comment for display in a single cell
        human_combined = f"EXACT: {gold_exact}\nCOMMENT: {gold_comment}"
        ai_combined = f"EXACT: {pred_exact}\nCOMMENT: {pred_comment}"

        # Add results to the list for this citation
        results[citation_number].append({
            "Entity Type": entity,
            "Human": human_combined,
            "AI": ai_combined,
        })

# Create a DataFrame for structured evaluation output
rows = []
columns = set()

for citation, entities in results.items():
    for entity_data in entities:
        entity_type = entity_data["Entity Type"]
        human_value = entity_data["Human"]
        ai_value = entity_data["AI"]

        # Ensure the row exists for the current entity type
        row = next((r for r in rows if r["Entity Type"] == entity_type), None)
        if not row:
            row = {"Entity Type": entity_type}
            rows.append(row)

        # Add human and AI data under the citation's subcolumns
        row[f"{citation} - Human"] = human_value
        row[f"{citation} - AI"] = ai_value

# Convert to DataFrame
df_citation_eval = pd.DataFrame(rows)

# Save the DataFrame as a CSV
output_csv_path = "data/evaluation_by_citation.csv"
df_citation_eval.to_csv(output_csv_path, index=False)

output_csv_path
# Out:
# 'data/evaluation_by_citation.csv'

# %%
df_citation_eval
# Out:
#                    Entity Type  \
# 0                     citation
# 1                       judges
# 2                ConvCourtName
# 3              ConvictPleaDate
# 4               ConvictOffence
# 5                AcquitOffence
# 6           ConfessPleadGuilty
# 7                    PleaPoint
# 8               RemandDecision
# 9            RemandCustodyTime
# 10               SentCourtName
# 11            SentenceReceived
# 12              SentenceServed
# 13              WhatAncilliary
# 14                      OffSex
# 15               OffAgeOffence
# 16               OffJobOffence
# 17              OffHomeOffence
# 18            OffMentalOffence
# 19             OffIntoxOffence
# 20              OffVicRelation
# 21                  VictimType
# 22                      VicNum
# 23                      VicSex
# 24               VicAgeOffence
# 25               VicJobOffence
# 26              VicHomeOffence
# 27            VicMentalOffence
# 28             VicIntoxOffence
# 29           ProsEvidTypeTrial
# 30            DefEvidTypeTrial
# 31               PreSentReport
# 32                 AggFactSent
# 33                 MitFactSent
# 34          VicImpactStatement
# 35                   Appellant
# 36                 CoDefAccNum
# 37               AppealAgainst
# 38                AppealGround
# 39              SentGuideWhich
# 40               AppealOutcome
# 41             ReasonQuashConv
# 42  ReasonSentExcessNotLenient
# 43  ReasonSentLenientNotExcess
# 44               ReasonDismiss
#
#                          [2024] EWCA Crim 474 - Human  \
# 0           EXACT: [2024] EWCA Crim 474\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE MALES', 'MR JUSTICE HILL...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                    EXACT: Don't know\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                    EXACT: Don't know\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                             [2024] EWCA Crim 474 - AI  \
# 0   EXACT: On 24 April 2024, Before: LORD JUSTICE ...
# 1   EXACT: Before: LORD JUSTICE MALES MR JUSTICE H...
# 2   EXACT: On 18 October 2022, in the Crown Court ...
# 3   EXACT: On 18 October 2022, in the Crown Court ...
# 4   EXACT: possessing MDMA (count 2), possessing c...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: the appellant (then aged 27) pleaded gu...
# 7   EXACT: On 18 October 2022, in the Crown Court ...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 21 December 2023, he was sentenced t...
# 11  EXACT: He was sentenced to concurrent terms of...
# 12  EXACT: He was sentenced to concurrent terms of...
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: the appellant (then aged 27)\nCOMMENT: ...
# 15   EXACT: the appellant (then aged 27)\nCOMMENT: 27
# 16  EXACT: He was self-employed in his own propert...
# 17  EXACT: He stayed with his wife occasionally at...
# 18                           EXACT: nan\nCOMMENT: nan
# 19                            EXACT: nan\nCOMMENT: No
# 20  EXACT: The driver was in possession of cash an...
# 21  EXACT: The driver was in possession of cash an...
# 22  EXACT: The driver was in possession of cash an...
# 23  EXACT: The driver was in possession of cash an...
# 24                           EXACT: nan\nCOMMENT: nan
# 25  EXACT: The driver was in possession of cash an...
# 26  EXACT: The driver was in possession of cash an...
# 27                           EXACT: nan\nCOMMENT: nan
# 28                            EXACT: nan\nCOMMENT: No
# 29  EXACT: Examination of the mobile telephone sho...
# 30  EXACT: When interviewed, the appellant said th...
# 31  EXACT: A pre-sentence report said that the app...
# 32  EXACT: The judge raised the starting point for...
# 33  EXACT: A pre-sentence report said that the app...
# 34                    EXACT: nan\nCOMMENT: Don’t know
# 35            EXACT: the appellant\nCOMMENT: Offender
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: It is now argued on the appellant’s beh...
# 38  EXACT: It is now argued on the appellant’s beh...
# 39  EXACT: The judge evidently had well in mind th...
# 40  EXACT: In these circumstances, and notwithstan...
# 41                           EXACT: nan\nCOMMENT: nan
# 42  EXACT: The obstacle faced by the appellant the...
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: Nor is any complaint made about the len...
#
#                         [2014] EWCA Crim 1594 - Human  \
# 0          EXACT: [2014] EWCA Crim 1594\nCOMMENT: nan
# 1   EXACT: ['MR JUSTICE GLOBE', 'SIR RODERICK EVAN...
# 2    EXACT: Crown Court at Inner London\nCOMMENT: nan
# 3                 EXACT: 14th June 2011\nCOMMENT: nan
# 4   EXACT: conspiracy to supply controlled drugs o...
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                              EXACT: -\nCOMMENT: nan
# 8                              EXACT: -\nCOMMENT: nan
# 9                              EXACT: -\nCOMMENT: nan
# 10   EXACT: Crown Court at Inner London\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                             EXACT: -\nCOMMENT: nan
# 14              EXACT: Vincent Graham,\nCOMMENT: male
# 15                             EXACT: -\nCOMMENT: nan
# 16                             EXACT: -\nCOMMENT: nan
# 17                             EXACT: -\nCOMMENT: nan
# 18                             EXACT: -\nCOMMENT: nan
# 19                             EXACT: -\nCOMMENT: nan
# 20                             EXACT: -\nCOMMENT: nan
# 21                             EXACT: -\nCOMMENT: nan
# 22                             EXACT: -\nCOMMENT: nan
# 23                             EXACT: -\nCOMMENT: nan
# 24                             EXACT: -\nCOMMENT: nan
# 25                             EXACT: -\nCOMMENT: nan
# 26                             EXACT: -\nCOMMENT: nan
# 27                             EXACT: -\nCOMMENT: nan
# 28                             EXACT: -\nCOMMENT: nan
# 29                             EXACT: -\nCOMMENT: nan
# 30                             EXACT: -\nCOMMENT: nan
# 31                             EXACT: -\nCOMMENT: nan
# 32                             EXACT: -\nCOMMENT: nan
# 33                             EXACT: -\nCOMMENT: nan
# 34                             EXACT: -\nCOMMENT: nan
# 35  EXACT: applicant, Vincent Graham, pleaded guil...
# 36                             EXACT: -\nCOMMENT: nan
# 37                             EXACT: -\nCOMMENT: nan
# 38                             EXACT: -\nCOMMENT: nan
# 39                             EXACT: -\nCOMMENT: nan
# 40                             EXACT: -\nCOMMENT: nan
# 41                             EXACT: -\nCOMMENT: nan
# 42                             EXACT: -\nCOMMENT: nan
# 43                             EXACT: -\nCOMMENT: nan
# 44                             EXACT: -\nCOMMENT: nan
#
#                            [2014] EWCA Crim 1594 - AI  \
# 0   EXACT: On 12th June 2014, this court, differen...
# 1   EXACT: PRESIDENT OF THE QUEEN\'S BENCH DIVISIO...
# 2   EXACT: On 14th June 2011 in the Crown Court at...
# 3   EXACT: On 14th June 2011 in the Crown Court at...
# 4   EXACT: the applicant, Vincent Graham, pleaded ...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: the applicant, Vincent Graham, pleaded ...
# 7   EXACT: On 14th June 2011 in the Crown Court at...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10                          EXACT: nan\nCOMMENT: null
# 11                          EXACT: nan\nCOMMENT: null
# 12                           EXACT: nan\nCOMMENT: nan
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: the applicant, Vincent Graham\nCOMMENT:...
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35  EXACT: the applicant, Vincent Graham\nCOMMENT:...
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: the application for leave to appeal is ...
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40  EXACT: the application for leave to appeal is ...
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: the application for leave to appeal is ...
#
#                          [2017] EWCA Crim 849 - Human  \
# 0           EXACT: [2017] EWCA Crim 849\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE HICKINBOTTOM', 'MR JUSTI...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                    EXACT: Don't know\nCOMMENT: nan
# 17                    EXACT: Don't know\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                    EXACT: Don't know\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                    EXACT: Don't know\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                             [2017] EWCA Crim 849 - AI  \
# 0   EXACT: IN THE COURT OF APPEAL CRIMINAL DIVISIO...
# 1   EXACT: LORD JUSTICE HICKINBOTTOM MR JUSTICE HO...
# 2   EXACT: On 18th August 2016 in the Crown Court ...
# 3     EXACT: On 18th August 2016\nCOMMENT: 2016-08-18
# 4   EXACT: an offence of aggravated burglary\nCOMM...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: The appellant pleaded guilty at an earl...
# 7   EXACT: On 18th August 2016 in the Crown Court ...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11  EXACT: On 10th February 2017 he was sentenced ...
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14  EXACT: The appellant was born in 1998 and is n...
# 15  EXACT: He was only 18 when he committed the of...
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21  EXACT: Those engaged in the tobacco business w...
# 22  EXACT: The property stolen included one reside...
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32  EXACT: He had however already been convicted o...
# 33  EXACT: The appellant was born in 1998 and is n...
# 34                           EXACT: nan\nCOMMENT: nan
# 35  EXACT: By leave of the single judge he now app...
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: contending that it is manifestly excess...
# 38  EXACT: The judge should have considered all th...
# 39                           EXACT: nan\nCOMMENT: nan
# 40              EXACT: nan\nCOMMENT: Dismissed-Failed
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                         [2015] EWCA Crim 1791 - Human  \
# 0          EXACT: [2015] EWCA Crim 1791\nCOMMENT: nan
# 1   EXACT: ['LADY JUSTICE RAFFERTY', 'MR JUSTICE H...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                             EXACT: No\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                    EXACT: Don't know\nCOMMENT: nan
# 17                    EXACT: Don't know\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                    EXACT: Don't know\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2015] EWCA Crim 1791 - AI  \
# 0   EXACT: IN THE COURT OF APPEAL (CRIMINAL DIVISI...
# 1   EXACT: Before: LADY JUSTICE RAFFERTY MR JUSTIC...
# 2   EXACT: ON APPEAL FROM CROWN COURT AT WOOLWICH\...
# 3      EXACT: On 12 October 2012\nCOMMENT: 2012-10-12
# 4   EXACT: 6 counts (2-3 and 9-12) of making indec...
# 5   EXACT: 6 further counts of making indecent ima...
# 6         EXACT: He did not plead guilty\nCOMMENT: No
# 7                  EXACT: At trial\nCOMMENT: At trial
# 8          EXACT: Not applicable\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: IN THE COURT OF APPEAL (CRIMINAL DIVISI...
# 11  EXACT: On 15 November 2012 he was sentenced to...
# 12             EXACT: Concurrent\nCOMMENT: Concurrent
# 13                           EXACT: nan\nCOMMENT: nan
# 14  EXACT: The appellant, 30 and of good character...
# 15  EXACT: The appellant, 30 and of good character...
# 16  EXACT: He worked for solicitors in their IT de...
# 17  EXACT: The appellant, 30 and of good character...
# 18                           EXACT: nan\nCOMMENT: nan
# 19        EXACT: He did not plead guilty\nCOMMENT: No
# 20                           EXACT: nan\nCOMMENT: nan
# 21  EXACT: indecent images of children\nCOMMENT: C...
# 22  EXACT: seventy-five were of children\nCOMMENT: 75
# 23  EXACT: indecent images of children\nCOMMENT: C...
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                            EXACT: nan\nCOMMENT: No
# 29  EXACT: The Crown’s case was that he had viewed...
# 30  EXACT: The defence was that the downloads were...
# 31                           EXACT: nan\nCOMMENT: nan
# 32  EXACT: The Crown contended that the file title...
# 33  EXACT: The defence was that the downloads were...
# 34  EXACT: The Crown contended that the file title...
# 35  EXACT: The appellant, 30 and of good character...
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: Grounds of appeal advanced by Mr James ...
# 38  EXACT: The judge erred in written directions o...
# 39  EXACT: s 1 (1) (a) Protection of Children Act ...
# 40    EXACT: This appeal is allowed\nCOMMENT: Allowed
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                         [2007] EWCA Crim 3312 - Human  ...  \
# 0          EXACT: [2007] EWCA Crim 3312\nCOMMENT: nan  ...
# 1   EXACT: ['LORD JUSTICE LAWS', 'MR JUSTICE MACKA...  ...
# 2             EXACT: Harrow Crown Court\nCOMMENT: nan  ...
# 3                 EXACT: 30 August 2007\nCOMMENT: nan  ...
# 4   EXACT: possession an offensive weapon\nCOMMENT...  ...
# 5                             EXACT: No\nCOMMENT: nan  ...
# 6                            EXACT: nan\nCOMMENT: nan  ...
# 7                            EXACT: nan\nCOMMENT: nan  ...
# 8                     EXACT: Don't know\nCOMMENT: nan  ...
# 9                     EXACT: Don't know\nCOMMENT: nan  ...
# 10            EXACT: Harrow Crown Court\nCOMMENT: nan  ...
# 11                           EXACT: nan\nCOMMENT: nan  ...
# 12                           EXACT: nan\nCOMMENT: nan  ...
# 13                           EXACT: nan\nCOMMENT: nan  ...
# 14                          EXACT: his\nCOMMENT: Male  ...
# 15                            EXACT: 35\nCOMMENT: nan  ...
# 16                    EXACT: Don't know\nCOMMENT: nan  ...
# 17                    EXACT: Don't know\nCOMMENT: nan  ...
# 18                    EXACT: Don't know\nCOMMENT: nan  ...
# 19                    EXACT: Don't know\nCOMMENT: nan  ...
# 20                           EXACT: nan\nCOMMENT: nan  ...
# 21                           EXACT: nan\nCOMMENT: nan  ...
# 22                           EXACT: nan\nCOMMENT: nan  ...
# 23                           EXACT: nan\nCOMMENT: nan  ...
# 24                           EXACT: nan\nCOMMENT: nan  ...
# 25                           EXACT: nan\nCOMMENT: nan  ...
# 26                           EXACT: nan\nCOMMENT: nan  ...
# 27                           EXACT: nan\nCOMMENT: nan  ...
# 28                           EXACT: nan\nCOMMENT: nan  ...
# 29  EXACT: evidence adduced before the jury as par...  ...
# 30           EXACT: self-defence gloves\nCOMMENT: nan  ...
# 31                    EXACT: Don't know\nCOMMENT: nan  ...
# 32                           EXACT: nan\nCOMMENT: nan  ...
# 33                           EXACT: nan\nCOMMENT: nan  ...
# 34                           EXACT: nan\nCOMMENT: nan  ...
# 35  EXACT: application by the prosecution\nCOMMENT...  ...
# 36                           EXACT: nan\nCOMMENT: nan  ...
# 37  EXACT: leave to appeal against a terminating r...  ...
# 38  EXACT: reverse the Recorder's ruling on the gr...  ...
# 39  EXACT: section 61 of the Criminal Justice Act ...  ...
# 40              EXACT: allow the appeal\nCOMMENT: nan  ...
# 41                           EXACT: nan\nCOMMENT: nan  ...
# 42  EXACT: In those circumstances we are satisfied...  ...
# 43                           EXACT: nan\nCOMMENT: nan  ...
# 44                           EXACT: nan\nCOMMENT: nan  ...
#
#                         [2016] EWCA Crim 1841 - Human  \
# 0          EXACT: [2016] EWCA Crim 1841\nCOMMENT: nan
# 1           EXACT: ['MR JUSTICE MALES']\nCOMMENT: nan
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                             EXACT: No\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                    EXACT: Don't know\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                    EXACT: Don't know\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20  EXACT: under the care of three members of staf...
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                    EXACT: Don't know\nCOMMENT: nan
# 27                            EXACT: No\nCOMMENT: nan
# 28                            EXACT: No\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                            EXACT: No\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2016] EWCA Crim 1841 - AI  \
# 0   EXACT: On APPEAL from the Crown Court at Notti...
# 1   EXACT: THE PRESIDENT OF THE QUEEN’S BENCH DIVI...
# 2   EXACT: IN THE COURT OF APPEAL (CRIMINAL DIVISI...
# 3      EXACT: On 4 November 2015\nCOMMENT: 2015-11-04
# 4   EXACT: Dr Hadiza Bawa-Garba was convicted of m...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: Dr Bawa-Garba now renews her applicatio...
# 7                           EXACT: nan\nCOMMENT: null
# 8                           EXACT: nan\nCOMMENT: null
# 9                           EXACT: nan\nCOMMENT: null
# 10                          EXACT: nan\nCOMMENT: null
# 11  EXACT: On 14 December 2015, she was sentenced ...
# 12  EXACT: the operation of which was suspended fo...
# 13                          EXACT: nan\nCOMMENT: null
# 14       EXACT: Dr Hadiza Bawa-Garba\nCOMMENT: Female
# 15                          EXACT: nan\nCOMMENT: null
# 16  EXACT: Dr Hadiza Bawa-Garba is a junior doctor...
# 17                          EXACT: nan\nCOMMENT: null
# 18                          EXACT: nan\nCOMMENT: null
# 19                          EXACT: nan\nCOMMENT: null
# 20                          EXACT: nan\nCOMMENT: null
# 21  EXACT: Jack Adcock, a six year old boy\nCOMMEN...
# 22                     EXACT: Jack Adcock\nCOMMENT: 1
# 23  EXACT: Jack Adcock, a six year old boy\nCOMMEN...
# 24                EXACT: six year old boy\nCOMMENT: 6
# 25                          EXACT: nan\nCOMMENT: null
# 26                          EXACT: nan\nCOMMENT: null
# 27                          EXACT: nan\nCOMMENT: null
# 28                          EXACT: nan\nCOMMENT: null
# 29  EXACT: The case concerns the care and treatmen...
# 30  EXACT: The case advanced on behalf of Dr Bawa-...
# 31                          EXACT: nan\nCOMMENT: null
# 32                          EXACT: nan\nCOMMENT: null
# 33                          EXACT: nan\nCOMMENT: null
# 34                          EXACT: nan\nCOMMENT: null
# 35  EXACT: HADIZA BAWA-GARBA\nAppellant\nCOMMENT: ...
# 36  EXACT: A nurse on duty at the time (Isabel Ama...
# 37  EXACT: Dr Bawa-Garba now renews her applicatio...
# 38                          EXACT: nan\nCOMMENT: null
# 39                          EXACT: nan\nCOMMENT: null
# 40  EXACT: In the circumstances, this renewed appl...
# 41                          EXACT: nan\nCOMMENT: null
# 42                          EXACT: nan\nCOMMENT: null
# 43                          EXACT: nan\nCOMMENT: null
# 44                          EXACT: nan\nCOMMENT: null
#
#                         [2019] EWCA Crim 1628 - Human  \
# 0          EXACT: [2019] EWCA Crim 1628\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE SIMON', 'MRS JUSTICE McG...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                     EXACT: Don't know\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                    EXACT: Don't know\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                    EXACT: Don't know\nCOMMENT: nan
# 16                    EXACT: Don't know\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18  EXACT: cutting his wrists\nCOMMENT: Mental hea...
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                    EXACT: Don't know\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2019] EWCA Crim 1628 - AI  \
# 0   EXACT: NCN: [2019] EWCA (Crim) 1628\nCOMMENT: ...
# 1   EXACT: B e f o r e : LORD JUSTICE SIMON MRS JU...
# 2   EXACT: On 8 March 2019 the appellant pleaded g...
# 3   EXACT: On 8 March 2019 the appellant pleaded g...
# 4   EXACT: pleaded guilty to two sexual offences i...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: On 8 March 2019 the appellant pleaded g...
# 7   EXACT: On 8 March 2019 the appellant pleaded g...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 8 March 2019 the appellant pleaded g...
# 11  EXACT: On 3 April he was sentenced by His Hono...
# 12  EXACT: The sentences were ordered to be served...
# 13  EXACT: A pre-sentence report recorded that the...
# 14  EXACT: The appellant was aged 20 at the date o...
# 15  EXACT: The appellant was aged 20 at the date o...
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18  EXACT: On 16 September 2018 the mother of the ...
# 19                           EXACT: nan\nCOMMENT: nan
# 20  EXACT: The messages on the download consisted ...
# 21  EXACT: The victim, JW, was 15 years old at the...
# 22  EXACT: The victim, JW, was 15 years old at the...
# 23  EXACT: The victim, JW, was 15 years old at the...
# 24  EXACT: The victim, JW, was 15 years old at the...
# 25                           EXACT: nan\nCOMMENT: nan
# 26  EXACT: On 16 September 2018 the mother of the ...
# 27  EXACT: On 16 September 2018 the mother of the ...
# 28                           EXACT: nan\nCOMMENT: nan
# 29  EXACT: The messages on the download consisted ...
# 30  EXACT: The appellant was asked about the CAWN ...
# 31  EXACT: A pre-sentence report recorded that the...
# 32  EXACT: The Judge added that there also seemed ...
# 33  EXACT: The Judge accepted that the appellant's...
# 34  EXACT: The Judge noted that the background had...
# 35  EXACT: The appellant appeals against the sente...
# 36  EXACT: The appellant was asked about the CAWN ...
# 37  EXACT: Ms Hartford-Bell submitted that the sen...
# 38  EXACT: Ms Hartford-Bell submitted that the Jud...
# 39  EXACT: The Judge referred to the Sentencing Co...
# 40  EXACT: The appeal will be allowed.\nCOMMENT: D...
# 41  EXACT: The Judge regarded it as material and s...
# 42  EXACT: The Judge added that there also seemed ...
# 43  EXACT: The Judge accepted that the appellant\'...
# 44  EXACT: The Judge referred to the Sentencing Co...
#
#                         [2007] EWCA Crim 2787 - Human  \
# 0          EXACT: [2007] EWCA Crim 2787\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE LATHAM', 'MR JUSTICE AIK...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                             EXACT: No\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                    EXACT: Don't know\nCOMMENT: nan
# 16                    EXACT: Don't know\nCOMMENT: nan
# 17                    EXACT: Don't know\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20                    EXACT: Don't know\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                    EXACT: Don't know\nCOMMENT: nan
# 26                    EXACT: Don't know\nCOMMENT: nan
# 27                    EXACT: Don't know\nCOMMENT: nan
# 28                    EXACT: Don't know\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                    EXACT: Don't know\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                    EXACT: Don't know\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2007] EWCA Crim 2787 - AI  \
# 0   EXACT: Neutral Citation Number: [2007] EWCA Cr...
# 1   EXACT: B e f o r e : LORD JUSTICE LATHAM Vice ...
# 2   EXACT: On 3rd March in the Crown Court at Tees...
# 3   EXACT: On 3rd March in the Crown Court at Tees...
# 4   EXACT: five counts of indecent assault on a fe...
# 5   EXACT: He was acquitted of one count in that s...
# 6   EXACT: The appellant\'s account is and always ...
# 7   EXACT: The appellant\'s account is and always ...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 3rd March in the Crown Court at Tees...
# 11  EXACT: He was sentenced to 3 years\' imprisonm...
# 12  EXACT: He was sentenced to 3 years\' imprisonm...
# 13                        EXACT: nan\nCOMMENT: [None]
# 14  EXACT: The victim of the alleged offences was ...
# 15  EXACT: The victim of the alleged offences was ...
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20  EXACT: The allegations against the appellant w...
# 21  EXACT: The victim of the alleged offences was ...
# 22  EXACT: The victim of the alleged offences was ...
# 23  EXACT: The victim of the alleged offences was ...
# 24  EXACT: The victim of the alleged offences was ...
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29  EXACT: Her evidence was supported, it was said...
# 30  EXACT: The appellant\'s account is and always ...
# 31                           EXACT: nan\nCOMMENT: nan
# 32                        EXACT: nan\nCOMMENT: [None]
# 33  EXACT: He was a man of previous good character...
# 34                           EXACT: nan\nCOMMENT: nan
# 35  EXACT: The man I represent has asked me today ...
# 36                             EXACT: nan\nCOMMENT: 0
# 37  EXACT: The reference is based upon four partic...
# 38  EXACT: There is now clear medical evidence to ...
# 39                        EXACT: nan\nCOMMENT: [None]
# 40  EXACT: The only order that we need make today ...
# 41  EXACT: There is now clear medical evidence to ...
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: It is not therefore pursued, and accord...
#
#                         [2004] EWCA Crim 2901 - Human  \
# 0          EXACT: [2004] EWCA Crim 2901\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE CLARKE', 'MR JUSTICE DOU...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                             EXACT: No\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                     EXACT: Don't know\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19                    EXACT: Don't know\nCOMMENT: nan
# 20         EXACT: look after him\nCOMMENT: Acquainted
# 21                           EXACT: nan\nCOMMENT: nan
# 22                          EXACT: M\nCOMMENT: 2 of 2
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                    EXACT: Don't know\nCOMMENT: nan
# 28                    EXACT: Don't know\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                    EXACT: Don't know\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40  EXACT: eight years is quashed and substituted ...
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2004] EWCA Crim 2901 - AI  \
# 0   EXACT: Neutral Citation Number: [2004] EWCA Cr...
# 1   EXACT: B E F O R E: LORD JUSTICE CLARKE MR JUS...
# 2   EXACT: On 1st December 2003, in the Crown Cour...
# 3    EXACT: On 1st December 2003\nCOMMENT: 2003-12-01
# 4   EXACT: one count of buggery, on which he was c...
# 5   EXACT: The jury acquitted him of two further c...
# 6   EXACT: The defence case was shortly as follows...
# 7   EXACT: This is the judgment of the court.\nCOM...
# 8   EXACT: The Recorder rejected an application, w...
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 12th February 2004 he was sentenced ...
# 11  EXACT: six years\' imprisonment for buggery wh...
# 12  EXACT: The total sentence was eight years\' im...
# 13  EXACT: The Recorder made an order under sectio...
# 14  EXACT: The complainant in counts 1 to 3, whom ...
# 15  EXACT: The defence case was shortly as follows...
# 16  EXACT: The defence case was shortly as follows...
# 17  EXACT: The defence case was shortly as follows...
# 18  EXACT: The defence case was shortly as follows...
# 19  EXACT: The defence case was shortly as follows...
# 20  EXACT: The complainant in counts 1 to 3, whom ...
# 21  EXACT: The complainant in counts 1 to 3, whom ...
# 22  EXACT: The complainant in counts 1 to 3, whom ...
# 23  EXACT: The complainant in counts 1 to 3, whom ...
# 24  EXACT: The complainant in counts 1 to 3, whom ...
# 25  EXACT: The complainant in counts 1 to 3, whom ...
# 26  EXACT: The complainant in counts 1 to 3, whom ...
# 27  EXACT: The complainant in counts 1 to 3, whom ...
# 28  EXACT: The complainant in counts 1 to 3, whom ...
# 29  EXACT: The Recorder rejected a defence submiss...
# 30  EXACT: The defence case was shortly as follows...
# 31  EXACT: The pre-sentence report does not sugges...
# 32  EXACT: The Recorder took into account the fact...
# 33  EXACT: The Recorder took into account the fact...
# 34  EXACT: The Recorder took into account the fact...
# 35  EXACT: The appellant appeals against his convi...
# 36  EXACT: The complainant in counts 1 to 3, whom ...
# 37  EXACT: The appellant appeals against his convi...
# 38  EXACT: The grounds of appeal against convictio...
# 39  EXACT: The Recorder made an order under sectio...
# 40  EXACT: The appeal against conviction fails.\nC...
# 41  EXACT: The Recorder rejected a defence submiss...
# 42  EXACT: The Recorder took into account the fact...
# 43  EXACT: The Recorder took into account the fact...
# 44  EXACT: The appeal against conviction fails.\nC...
#
#                         [2018] EWCA Crim 1374 - Human  \
# 0          EXACT: [2018] EWCA Crim 1374\nCOMMENT: nan
# 1   EXACT: ['LORD JUSTICE SIMON', 'MR JUSTICE GOOS...
# 2   EXACT: Crown Court at Stoke-on-Trent\nCOMMENT:...
# 3                EXACT: 22 January 2018\nCOMMENT: nan
# 4   EXACT: possession of a controlled drug of clas...
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7   EXACT: pleaded guilty after his further arrest...
# 8            EXACT: he was granted bail\nCOMMENT: nan
# 9                     EXACT: Don't know\nCOMMENT: nan
# 10  EXACT: Crown Court at Stoke-on-Trent\nCOMMENT:...
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                    EXACT: Don't know\nCOMMENT: nan
# 14                           EXACT: He\nCOMMENT: male
# 15                            EXACT: 40\nCOMMENT: nan
# 16                    EXACT: Don't know\nCOMMENT: nan
# 17                    EXACT: Don't know\nCOMMENT: nan
# 18                    EXACT: Don't know\nCOMMENT: nan
# 19  EXACT: appellant was a drug addict\nCOMMENT: y...
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29  EXACT: found to be in possession of 3.05 grams...
# 30  EXACT: appellant was a drug addict whose suppl...
# 31                    EXACT: Don't know\nCOMMENT: nan
# 32  EXACT: motivated by financial or other advanta...
# 33                EXACT: pleaded guilty\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35  EXACT: he appellant, Christopher Fletcher, who...
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: sentence\nCOMMENT: appeal against sentence
# 38  EXACT: there should have been a greater reduct...
# 39  EXACT: section 5(3) of the Misuse of Drugs Act...
# 40                       EXACT: dismiss\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42  EXACT: there should have been a greater reduct...
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: There were significant aggravating feat...
#
#                            [2018] EWCA Crim 1374 - AI
# 0   EXACT: On 22 January 2018, the appellant, Chri...
# 1   EXACT: B e f o r e : LORD JUSTICE SIMON MR JUS...
# 2   EXACT: He was sentenced in the Crown Court at ...
# 3      EXACT: On 22 January 2018\nCOMMENT: 2018-01-22
# 4   EXACT: He had pleaded guilty to drugs offences...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: He had pleaded guilty to drugs offences...
# 7   EXACT: He had pleaded guilty after his further...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: He was sentenced in the Crown Court at ...
# 11  EXACT: He was sentenced to imprisonment for 8 ...
# 12  EXACT: He was sentenced to 4 years' imprisonme...
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: The appellant, Christopher Fletcher, wh...
# 15  EXACT: The appellant, Christopher Fletcher, wh...
# 16  EXACT: The facts of these offences can be star...
# 17                    EXACT: nan\nCOMMENT: Don’t know
# 18                    EXACT: nan\nCOMMENT: Don’t know
# 19                    EXACT: nan\nCOMMENT: Don’t know
# 20                    EXACT: nan\nCOMMENT: Don’t know
# 21                          EXACT: nan\nCOMMENT: null
# 22                    EXACT: nan\nCOMMENT: Don’t know
# 23                    EXACT: nan\nCOMMENT: Don’t know
# 24                    EXACT: nan\nCOMMENT: Don’t know
# 25                    EXACT: nan\nCOMMENT: Don’t know
# 26                    EXACT: nan\nCOMMENT: Don’t know
# 27                    EXACT: nan\nCOMMENT: Don’t know
# 28                    EXACT: nan\nCOMMENT: Don’t know
# 29                          EXACT: nan\nCOMMENT: null
# 30                          EXACT: nan\nCOMMENT: null
# 31                    EXACT: nan\nCOMMENT: Don’t know
# 32  EXACT: Further, given that the second indictme...
# 33                          EXACT: nan\nCOMMENT: null
# 34                    EXACT: nan\nCOMMENT: Don’t know
# 35  EXACT: The appellant, Christopher Fletcher\nCO...
# 36                    EXACT: nan\nCOMMENT: Don’t know
# 37  EXACT: The appellant appeals with leave from t...
# 38  EXACT: No criticism is made of the consecutive...
# 39  EXACT: The guideline for supplying or offering...
# 40  EXACT: In the circumstances, we dismiss this a...
# 41                          EXACT: nan\nCOMMENT: null
# 42                          EXACT: nan\nCOMMENT: null
# 43                          EXACT: nan\nCOMMENT: null
# 44  EXACT: Having committed a similar offence in 2...
#
# [45 rows x 251 columns]

# %%
import json
import sys
import yaml
import re
# List of entity types we want to evaluate
ENTITY_TYPES = [
    "citation",
    "judges",
    "ConvCourtName",
    "ConvictPleaDate",
    "ConvictOffence",
    "AcquitOffence",
    "ConfessPleadGuilty",  # Adjusted entity name to match YAML sample
    "PleaPoint",
    "RemandDecision",
    "RemandCustodyTime",
    "SentCourtName",
    "SentenceReceived",
    "SentenceServed",
    "WhatAncilliary",
    "OffSex",
    "OffAgeOffence",
    "OffJobOffence",
    "OffHomeOffence",
    "OffMentalOffence",
    "OffIntoxOffence",
    "OffVicRelation",
    "VictimType",
    "VicNum",
    "VicSex",
    "VicAgeOffence",
    "VicJobOffence",
    "VicHomeOffence",
    "VicMentalOffence",
    "VicIntoxOffence",
    "ProsEvidTypeTrial",
    "DefEvidTypeTrial",
    "PreSentReport",
    "AggFactSent",
    "MitFactSent",
    "VicImpactStatement",
    "Appellant",
    "CoDefAccNum",
    "AppealAgainst",
    "AppealGround",
    "SentGuideWhich",
    "AppealOutcome",
    "ReasonQuashConv",
    "ReasonSentExcessNotLenient",
    "ReasonSentLenientNotExcess",
    "ReasonDismiss",
]

def is_empty(val):
    """Determine if a value is effectively empty or non-informative."""
    if val is None:
        return True
    if isinstance(val, str):
        cleaned = val.strip().lower()
        if cleaned in ["", "nan", "null", "-"]:
            return True
    return False

def compute_metrics_from_counts(tp, fp, fn):
    """Compute precision, recall, and F1 given counts of TP, FP, FN."""
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    return precision, recall, f1

def fix_single_quotes(yaml_text):
    """
    Fix single-quote and scalar issues in YAML, ensuring proper quoting and escaping.
    """
    # Fix improperly quoted strings
    pattern = re.compile(r"(^\s*[^:]+:\s*)'(.*?)'(\s*(?:\n|$))", re.MULTILINE)
    def replacer(match):
        prefix, content, suffix = match.groups()
        fixed_content = content.replace("'", "''")  # Escape single quotes
        return f"{prefix}'''{fixed_content}'''{suffix}"
    fixed_text = pattern.sub(replacer, yaml_text)

    # Ensure all unquoted scalar values are wrapped in double quotes
    pattern_unquoted = re.compile(r"(^\s*[^:]+:\s*)([^\s\n\"'][^\n]*)(\n|$)", re.MULTILINE)
    def wrap_unquoted(match):
        prefix, value, suffix = match.groups()
        return f'{prefix}"{value.strip()}"{suffix}'
    fixed_text = pattern_unquoted.sub(wrap_unquoted, fixed_text)

    return fixed_text


def preprocess_yaml(yaml_text):
    """
    Fix common issues in YAML for parsing, ensuring proper quoting and escaping.
    """
    # Fix misplaced or dangling quotes
    yaml_text = re.sub(r'"([^"]*)"\s+([^"\n]+)(?=\n|$)', r'"\1 \2"', yaml_text)

    # Escape single and double quotes within strings
    yaml_text = yaml_text.replace("'", "''").replace('"', '\\"')

    return yaml_text


def parse_yaml_content(text):
    """
    Parse YAML with fixes for quoting and syntax issues.
    """
    # Remove YAML fences if present
    if text.startswith("```yaml"):
        text = text.replace("```yaml", "", 1)
    if text.endswith("```"):
        text = text[:-len("```")]

    # Fix syntax issues
    text = preprocess_yaml(text)
    text = fix_single_quotes(text)

    # Parse the corrected YAML
    yaml_data = yaml.safe_load(text)

    # Replace empty values with "nan"
    def replace_empty(data):
        if isinstance(data, dict):
            return {k: replace_empty(v) for k, v in data.items()}
        elif isinstance(data, list):
            return [replace_empty(item) for item in data]
        elif is_empty(data):
            return "nan"
        else:
            return data

    return replace_empty(yaml_data)


# def fix_single_quotes(yaml_text):
#     """
#     Fix single-quote issues in YAML and quote unquoted Exact values.
#     """
#     # Fix single-quoted strings
#     pattern = re.compile(r"(^\s*[^:]+:\s*)'(.*?)'(\s*(?:\n|$))", re.MULTILINE)
    
#     def replacer(match):
#         prefix = match.group(1)
#         content = match.group(2)
#         suffix = match.group(3)
#         fixed_content = content.replace("'", "''")
#         return f"{prefix}'{fixed_content}'{suffix}"
    
#     fixed_text = pattern.sub(replacer, yaml_text)
    
#     # Wrap unquoted Exact: values in double quotes to handle problematic characters
#     pattern_exact = re.compile(r"(^\s*Exact:\s*)([^\n]+)(\n|$)", re.MULTILINE)
    
#     def replacer_exact(match):
#         prefix = match.group(1)
#         value = match.group(2)
#         suffix = match.group(3)
#         # If value isn't already quoted, wrap it in quotes
#         if not (value.startswith('"') or value.startswith("'")):
#             fixed_value = value.replace("'", "''")  # double single quotes inside value
#             return f'{prefix}"{fixed_value}"{suffix}'
#         else:
#             return match.group(0)
    
#     fixed_text = pattern_exact.sub(replacer_exact, fixed_text)
#     return fixed_text

# def parse_yaml_content(text):
#     """
#     Parse YAML from the provided text, fixing quote issues and standardizing empty values to 'nan'.
#     """
#     # Remove markdown fences if present
#     if text.startswith("```yaml"):
#         text = text.replace("```yaml", "", 1)
#     if text.endswith("```"):
#         text = text[:-len("```")]

#     # Preprocess YAML to fix common syntax issues
#     text = preprocess_yaml(text)

#     # Fix single-quote issues
#     text_fixed = fix_single_quotes(text)

#     # Parse the corrected YAML content
#     yaml_data = yaml.safe_load(text_fixed)

#     # Standardize empty or dash values to 'nan'
#     def standardize_values(data):
#         if isinstance(data, dict):
#             return {
#                 key: standardize_values(value)
#                 for key, value in data.items()
#             }
#         elif isinstance(data, list):
#             return [standardize_values(item) for item in data]
#         elif data in ["-", ""]:
#             return "nan"
#         else:
#             return data

#     return standardize_values(yaml_data)

# def preprocess_yaml(yaml_text):
#     """
#     Fix common issues in YAML content for parsing, including misplaced or missing quotes.
#     """
#     # Ensure all scalar values are properly quoted
#     yaml_text = re.sub(r'(?<=:\s)([^\s"\'][^\n]*[^\s"\'])(?=\n|$)', r'"\1"', yaml_text)

#     # Fix misplaced quotes by combining partial quoted strings
#     yaml_text = re.sub(r'"([^"]*)"\s+([^"\n]+)(?=\n|$)', r'"\1 \2"', yaml_text)

#     # Escape double quotes within quoted strings
#     yaml_text = re.sub(r'(?<!\\)"', r'\\"', yaml_text)

#     return yaml_text

# %%
# !pip install ruamel.yaml
# Out:
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 3.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 16.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml
# Successfully installed ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import re

def parse_custom_text(input_text):
    """
    Parse the provided string into structured data using specific delimiters and patterns.
    """
    # Split into sections based on `\n` and look for patterns with 'Comment:' and 'Exact:'
    sections = input_text.split("\n")
    structured_data = []
    current_section = {}
    current_key = None

    for line in sections:
        # Check for section header (e.g., citation:)
        section_match = re.match(r"^(\w+):$", line.strip())
        if section_match:
            # Save the current section if it exists
            if current_section:
                structured_data.append(current_section)
                current_section = {}
            # Start a new section
            current_key = section_match.group(1)
            current_section["section"] = current_key
            continue

        # Check for Comment line
        comment_match = re.match(r"^\s*Comment:\s*(.*)$", line.strip())
        if comment_match:
            current_section["Comment"] = comment_match.group(1).strip("'") or "nan"
            continue

        # Check for Exact line
        exact_match = re.match(r"^\s*Exact:\s*(.*)$", line.strip())
        if exact_match:
            current_section["Exact"] = exact_match.group(1).strip("'") or "nan"
            continue

    # Append the last section if it exists
    if current_section:
        structured_data.append(current_section)

    return structured_data


# Example input
input_text = """
citation:
  Comment: '[2024] EWCA Crim 474'
  Exact: 'On 24 April 2024, Before: LORD JUSTICE MALES MR JUSTICE HILLIARD RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO) (Sitting as a Judge of the CACD) REX V RAJAK MIAH'

judges:
  Comment: 'LORD JUSTICE MALES, MR JUSTICE HILLIARD, RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO)'
  Exact: 'Before: LORD JUSTICE MALES MR JUSTICE HILLIARD RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO) (Sitting as a Judge of the CACD)'
"""

# Parse the text
parsed_data = parse_custom_text(input_text)

# Print the output
print(parsed_data)
# Out:
# [{'section': 'citation', 'Comment': '[2024] EWCA Crim 474', 'Exact': 'On 24 April 2024, Before: LORD JUSTICE MALES MR JUSTICE HILLIARD RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO) (Sitting as a Judge of the CACD) REX V RAJAK MIAH'}, {'section': 'judges', 'Comment': 'LORD JUSTICE MALES, MR JUSTICE HILLIARD, RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO)', 'Exact': 'Before: LORD JUSTICE MALES MR JUSTICE HILLIARD RECORDER OF NORTHAMPTON (HIS HONOUR JUDGE MAYO) (Sitting as a Judge of the CACD)'}]

# %%
entity_stats = { entity: {"TP": 0, "FP": 0, "FN": 0} for entity in ENTITY_TYPES }

total_tp = total_fp = total_fn = 0


json_file_path='/home/stirunag/Downloads/sft_on_english_data/sft_on_english_data/predictions/llama_3.1_8b_instruct_fine_tuned_appealcourt_coded/outputs_42.json'


with open(json_file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

data[1]

# %%
# Out:
# {'answer': '```yaml\ncitation:\n  Comment: \'[2014] EWCA Crim 1594\'\n  Exact: \'On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious.\'\n\njudges:\n  Comment: \'PRESIDENT OF THE QUEEN\\\'S BENCH DIVISION (SIR BRIAN LEVESON), MR JUSTICE GLOBE, SIR RODERICK EVANS\'\n  Exact: \'PRESIDENT OF THE QUEEN\\\'S BENCH DIVISION: 1. On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious.\'\n\nConvCourtName:\n  Comment: \'Crown Court at Inner London, Stockport Magistrates\\\' Court\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A. The application for leave to appeal was signed "Mr Mark O\\\'Connor Henry\\\'s Solicitors" after which the address is repeated. The solicitor with conduct of the case was in Stockport Magistrates\\\' Court\'\n\nConvictPleaDate:\n  Comment: \'2011-06-14\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nConvictOffence:\n  Comment: \'Conspiracy to supply controlled drugs of Class A\'\n  Exact: \'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nAcquitOffence:\n  Comment: \'null\'\n  Exact: \'\'\n\nConfessPleadGuilty:\n  Comment: \'Yes\'\n  Exact: \'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nPleaPoint:\n  Comment: \'at first court appearance\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nRemandDecision:\n  Comment: \'Don’t know\'\n  Exact: \'\'\n\nRemandCustodyTime:\n  Comment: \'nan\'\n  Exact: \'\'\n\nSentCourtName:\n  Comment: \'null\'\n  Exact: \'\'\n\nSentenceReceived:\n  Comment: \'null\'\n  Exact: \'\'\n\nSentenceServed:\n  Comment: \'nan\'\n  Exact: \'\'\n\nWhatAncilliary:\n  Comment: \'null\'\n  Exact: \'\'\n\nOffSex:\n  Comment: \'Male\'\n  Exact: \'the applicant, Vincent Graham\'\n\nOffAgeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffJobOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffHomeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffMentalOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffIntoxOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffVicRelation:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVictimType:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicNum:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicSex:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicAgeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicJobOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicHomeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicMentalOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicIntoxOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nProsEvidTypeTrial:\n  Comment: \'nan\'\n  Exact: \'\'\n\nDefEvidTypeTrial:\n  Comment: \'nan\'\n  Exact: \'\'\n\nPreSentReport:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAggFactSent:\n  Comment: \'nan\'\n  Exact: \'\'\n\nMitFactSent:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicImpactStatement:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAppellant:\n  Comment: \'Offender\'\n  Exact: \'the applicant, Vincent Graham\'\n\nCoDefAccNum:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAp ...
#  'gold': "citation:\n  Comment: nan\n  Exact: [2014] EWCA Crim 1594\njudges:\n  Comment: nan\n  Exact: ['MR JUSTICE GLOBE', 'SIR RODERICK EVANS']\n\n  ConvCourtName:\n    Comment: nan\n    Exact: Crown Court at Inner London\n  ConvictPleaDate:\n    Comment: nan\n    Exact: 14th June 2011\n  ConvictOffence:\n    Comment: nan\n    Exact: conspiracy to supply controlled drugs of Class A\n  AcquitOffence:\n    Comment: nan\n    Exact: nan\n  Confess/Plead :\n    Comment: nan\n    Exact: nan\n  PleaPoint:\n    Comment: nan\n    Exact: -\n  RemandDecision:\n    Comment: nan\n    Exact: -\n  RemandCustodyTime:\n    Comment: nan\n    Exact: -\n  SentCourtName:\n    Comment: nan\n    Exact: Crown Court at Inner London\n  Sentence:\n    Comment: nan\n    Exact: -\n  SentServe:\n    Comment: nan\n    Exact: -\n  WhatAncilliary:\n    Comment: nan\n    Exact: -\n  OffSex:\n    Comment: male\n    Exact: Vincent Graham,\n  OffAgeOffence:\n    Comment: nan\n    Exact: -\n  OffJobOffence:\n    Comment: nan\n    Exact: -\n  OffHomeOffence:\n    Comment: nan\n    Exact: -\n  OffMentalOffence:\n    Comment: nan\n    Exact: -\n  OffIntoxOffence:\n    Comment: nan\n    Exact: -\n  OffVicRelation:\n    Comment: nan\n    Exact: -\n  VictimType:\n    Comment: nan\n    Exact: -\n  VicNum:\n    Comment: nan\n    Exact: -\n  VicSex:\n    Comment: nan\n    Exact: -\n  VicAgeOffence:\n    Comment: nan\n    Exact: -\n  VicJobOffence:\n    Comment: nan\n    Exact: -\n  VicHomeOffence:\n    Comment: nan\n    Exact: -\n  VicMentalOffence:\n    Comment: nan\n    Exact: -\n  VicIntoxOffence:\n    Comment: nan\n    Exact: -\n  ProsEvidTypeTrial:\n    Comment: nan\n    Exact: -\n  DefEvidTypeTrial:\n    Comment: nan\n    Exact: -\n  PreSentReport:\n    Comment: nan\n    Exact: -\n  AggFactSent:\n    Comment: nan\n    Exact: -\n  MitFactSent:\n    Comment: nan\n    Exact: -\n  VicImpactStatement:\n    Comment: nan\n    Exact: -\n  Appellant:\n    Comment: offender\n    Exact: applicant, Vincent Graham, pleaded guilty to\n  CoDefAccNum:\n    Comment: nan\n    Exact: -\n  AppealAgainst:\n    Comment: nan\n    Exact: -\n  AppealGround:\n    Comment: nan\n    Exact: -\n  SentGuideWhich:\n    Comment: nan\n    Exact: -\n  AppealOutcome:\n    Comment: nan\n    Exact: -\n  ReasonQuashConv:\n    Comment: nan\n    Exact: -\n  ReasonSentExcessNotLenient:\n    Comment: nan\n    Exact: -\n  ReasonSentLenientNotExcess:\n    Comment: nan\n    Exact: -\n  ReasonDismiss:\n    Comment: nan\n    Exact: -\n"}

# %%
answer_text = data[1].get("answer", "")
gold_text = data[1].get("gold", "")

answer_yaml = parse_yaml_content(answer_text) or {}
gold_yaml = parse_yaml_content(gold_text) or {}
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 4
#       1 answer_text = data[1].get("answer", "")
#       2 gold_text = data[1].get("gold", "")
# ----> 4 answer_yaml = parse_yaml_content(answer_text) or {}
#       5 gold_yaml = parse_yaml_content(gold_text) or {}
#
# Cell In[6], line 121, in parse_yaml_content(text)
#     118 text = fix_single_quotes(text)
#     120 # Parse the corrected YAML
# --> 121 yaml_data = yaml.safe_load(text)
#     123 # Replace empty values with "nan"
#     124 def replace_empty(data):
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/__init__.py:125, in safe_load(stream)
#     117 def safe_load(stream):
#     118     """
#     119     Parse the first YAML document in a stream
#     120     and produce the corresponding Python object.
#    (...)
#     123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
#      83     loader.dispose()
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/constructor.py:49, in BaseConstructor.get_single_data(self)
#      47 def get_single_data(self):
#      48     # Ensure that the stream contains a single document and construct it.
# ---> 49     node = self.get_single_node()
#      50     if node is not None:
#      51         return self.construct_document(node)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/composer.py:36, in Composer.get_single_node(self)
#      34 document = None
#      35 if not self.check_event(StreamEndEvent):
# ---> 36     document = self.compose_document()
#      38 # Ensure that the stream contains no more documents.
#      39 if not self.check_event(StreamEndEvent):
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/composer.py:55, in Composer.compose_document(self)
#      52 self.get_event()
#      54 # Compose the root node.
# ---> 55 node = self.compose_node(None, None)
#      57 # Drop the DOCUMENT-END event.
#      58 self.get_event()
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/composer.py:84, in Composer.compose_node(self, parent, index)
#      82     node = self.compose_sequence_node(anchor)
#      83 elif self.check_event(MappingStartEvent):
# ---> 84     node = self.compose_mapping_node(anchor)
#      85 self.ascend_resolver()
#      86 return node
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/composer.py:127, in Composer.compose_mapping_node(self, anchor)
#     125 if anchor is not None:
#     126     self.anchors[anchor] = node
# --> 127 while not self.check_event(MappingEndEvent):
#     128     #key_event = self.peek_event()
#     129     item_key = self.compose_node(node, None)
#     130     #if item_key in node.value:
#     131     #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132     #            "found duplicate key", key_event.start_mark)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/parser.py:98, in Parser.check_event(self, *choices)
#      96 if self.current_event is None:
#      97     if self.state:
# ---> 98         self.current_event = self.state()
#      99 if self.current_event is not None:
#     100     if not choices:
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/yaml/parser.py:438, in Parser.parse_block_mapping_key(self)
#     436 if not self.check_token(BlockEndToken):
#     437     token = self.peek_token()
# --> 438     raise ParserError("while parsing a block mapping", self.marks[-1],
#     439             "expected <block end>, but found %r" % token.id, token.start_mark)
#     440 token = self.get_token()
#     441 event = MappingEndEvent(token.start_mark, token.end_mark)
#
# ParserError: while parsing a block mapping
#   in "<unicode string>", line 2, column 1:
#     citation:
#     ^
# expected <block end>, but found '<block mapping start>'
#   in "<unicode string>", line 4, column 3:
#       Exact: '''''On 12th June 2014, t ...
#       ^

# %%
answer_yaml

# %%
gold_yaml
# Out:
# {'citation': {'Comment': 'nan', 'Exact': '[2014] EWCA Crim 1594'},
#  'judges': {'Comment': 'nan',
#   'Exact': "[''MR JUSTICE GLOBE'', ''SIR RODERICK EVANS'']",
#   'ConvCourtName': {'Comment': 'nan', 'Exact': 'Crown Court at Inner London'},
#   'ConvictPleaDate': {'Comment': 'nan', 'Exact': '14th June 2011'},
#   'ConvictOffence': {'Comment': 'nan',
#    'Exact': 'conspiracy to supply controlled drugs of Class A'},
#   'AcquitOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'Confess/Plead': {'Comment': 'nan', 'Exact': 'nan'},
#   'PleaPoint': {'Comment': 'nan', 'Exact': 'nan'},
#   'RemandDecision': {'Comment': 'nan', 'Exact': 'nan'},
#   'RemandCustodyTime': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentCourtName': {'Comment': 'nan', 'Exact': 'Crown Court at Inner London'},
#   'Sentence': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentServe': {'Comment': 'nan', 'Exact': 'nan'},
#   'WhatAncilliary': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffSex': {'Comment': 'male', 'Exact': 'Vincent Graham,'},
#   'OffAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffVicRelation': {'Comment': 'nan', 'Exact': 'nan'},
#   'VictimType': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicNum': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicSex': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'ProsEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#   'DefEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#   'PreSentReport': {'Comment': 'nan', 'Exact': 'nan'},
#   'AggFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#   'MitFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicImpactStatement': {'Comment': 'nan', 'Exact': 'nan'},
#   'Appellant': {'Comment': 'offender',
#    'Exact': 'applicant, Vincent Graham, pleaded guilty to'},
#   'CoDefAccNum': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealAgainst': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealGround': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentGuideWhich': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealOutcome': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonQuashConv': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonSentExcessNotLenient': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonSentLenientNotExcess': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonDismiss': {'Comment': 'nan', 'Exact': 'nan'}}}

# %%
from difflib import SequenceMatcher

def similarity(a, b):
    """Compute similarity ratio between two strings."""
    return SequenceMatcher(None, a, b).ratio()

SIMILARITY_THRESHOLD = 0.5  # Adjust based on acceptable similarity level

# %%
# Process each record
for record in data:
    answer_text = record.get("answer", "")
    gold_text = record.get("gold", "")

    # Parse YAML content from answer and gold fields
    try:
        answer_yaml = parse_yaml_content(answer_text) or {}
    except Exception as e:
        print(f"Error parsing answer YAML: {e}")
        answer_yaml = {}
    try:
        gold_yaml = parse_yaml_content(gold_text) or {}
    except Exception as e:
        print(f"Error parsing gold YAML: {e}")
        gold_yaml = {}

    for entity in ENTITY_TYPES:
        # Extract "Comment" and "Exact" values
        gold_entity = gold_yaml.get(entity, {}) if isinstance(gold_yaml, dict) else {}
        pred_entity = answer_yaml.get(entity, {}) if isinstance(answer_yaml, dict) else {}
    
        gold_comment = gold_entity.get("Comment") if isinstance(gold_entity, dict) else None
        pred_comment = pred_entity.get("Comment") if isinstance(pred_entity, dict) else None
    
        gold_exact = gold_entity.get("Exact") if isinstance(gold_entity, dict) else None
        pred_exact = pred_entity.get("Exact") if isinstance(pred_entity, dict) else None
    
        # Initialize stats for the entity
        if entity not in entity_stats:
            entity_stats[entity] = {"TP": 0, "FP": 0, "FN": 0}
    
        # Function to update TP, FP, FN based on match
        def update_metrics(gold, pred):
            gold_present = not is_empty(gold)
            pred_present = not is_empty(pred)
            if gold_present:
                if pred_present:
                    # Check for similarity
                    if similarity(str(gold).strip(), str(pred).strip()) >= SIMILARITY_THRESHOLD:
                        entity_stats[entity]["TP"] += 1
                        return 1, 0, 0  # TP
                    else:
                        # Similarity below threshold
                        return 0, 1, 1  # FP, FN
                else:
                    # Gold present but prediction missing
                    return 0, 0, 1  # FN
            else:
                if pred_present:
                    # Prediction made but nothing in gold
                    return 0, 1, 0  # FP
                # Neither present: do nothing
                return 0, 0, 0
    
        # Update metrics for "Comment"
        tp, fp, fn = update_metrics(gold_comment, pred_comment)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
        # Update metrics for "Exact"
        tp, fp, fn = update_metrics(gold_exact, pred_exact)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
    # Print per-entity metrics
    # print("Per-Entity Metrics:\n")
    # for entity in ENTITY_TYPES:
    #     stats = entity_stats[entity]
    #     precision, recall, f1 = compute_metrics_from_counts(stats["TP"], stats["FP"], stats["FN"])
    #     print(f"{entity:25s} P={precision:.3f}  R={recall:.3f}  F1={f1:.3f}  (TP={stats['TP']}, FP={stats['FP']}, FN={stats['FN']})")
    
# Compute overall micro-averaged metrics
overall_precision, overall_recall, overall_f1 = compute_metrics_from_counts(total_tp, total_fp, total_fn)
print("\nOverall (Micro-Averaged) Metrics:")
print(f"Precision = {overall_precision:.3f}")
print(f"Recall    = {overall_recall:.3f}")
print(f"F1        = {overall_f1:.3f}")
# Out:
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2024] EWCA Crim 474'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2024]" EWCA Crim 474:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 1594'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 1594:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA 849 (Crim)
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 849:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 1791'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1791:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2007] EWCA Crim 3312'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 3312:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2004]" EWCA Crim 1528
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 1528:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2019] EWCA Crim 1570'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2019]" EWCA Crim 1570:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2011] EWCA Crim 1183'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2011]" EWCA Crim 1183:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2022] EWCA Crim 478'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2022]" EWCA Crim 478:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 2215
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 2215:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2023] EWCA Crim 1252'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2023]" EWCA Crim 1252:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2010]" EWCA Crim 1949
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 1949:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2004]" EWCA Crim 2674
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 2674:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA Crim 2508
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 2508:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2008]" EWCA Crim 248
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 248:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2018] EWCA Crim 328'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2018]" EWCA Crim 328:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 628'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 628:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2017] EWCA Crim 1277'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 1277:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2012]" EWCA Crim 1476
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2012]" EWCA Crim 1476:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2008] EWCA Crim 1027'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 1027:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2019] EWCA Crim 598'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2019]" EWCA Crim 598:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 2140
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 2140:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2023] EWCA Crim 200'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2023]" EWCA Crim 200:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2020] EWCA Crim 1540'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2020]" EWCA Crim 1540:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 3027
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 3027:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2020] EWCA Crim 673'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2020]" EWCA Crim 673:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2010] EWCA Crim 2405'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 2405:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 383'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 383:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2017] EWCA Crim 37'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 37:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2014]" EWCA Crim 53
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 53:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2024] EWCA Crim 104'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2024]" EWCA Crim 104:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2005]" EWCA Crim 1828
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2005]" EWCA Crim 1828:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2018] EWCA Crim 2485'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2018]" EWCA Crim 2485:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2010]" EWCA Crim 700
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 700:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 2413
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 2413:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2013] EWCA Crim 1394'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2013]" EWCA Crim 1394:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2016] EWCA Crim 1543'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2016]" EWCA Crim 1543:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2011]" EWCA Crim 459
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2011]" EWCA Crim 459:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 945'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 945:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 2907'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 2907:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2024] EWCA Crim 257'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2024]" EWCA Crim 257:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2003] EWCA Crim 3486'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 3486:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2007] EWCA Crim 234'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 234:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2022]" EWCA Crim 1548
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2022]" EWCA Crim 1548:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2008]" EWCA Crim 1308
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 1308:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2016]" EWCA Crim 1631
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2016]" EWCA Crim 1631:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2009] EWCA Crim 1942'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2009]" EWCA Crim 1942:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA Crim 648
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 648:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2023] EWCA Crim 661'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2023]" EWCA Crim 661:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2005]" EWCA Crim 3429
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2005]" EWCA Crim 3429:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2003]" EWCA Crim 3003
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 3003:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2018]" EWCA Crim 1068
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2018]" EWCA Crim 1068:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 876
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 876:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2014]" EWCA Crim 734
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 734:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2010]" EWCA Crim 372
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 372:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2003]" EWCA Crim 1555
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 1555:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA Crim 2062
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 2062:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2009] EWCA Crim 602'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2009]" EWCA Crim 602:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2006]" EWCA Crim 510
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2006]" EWCA Crim 510:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2005] EWCA Crim 703'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2005]" EWCA Crim 703:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2020] EWCA Crim 1748'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2020]" EWCA Crim 1748:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA Crim 1168
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 1168:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2010] EWCA Crim 3052'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 3052:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 421'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 421:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2004] EWCA Crim 3387'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 3387:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2003] EWCA Crim 419'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 419:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 1308'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1308:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2008] EWCA Crim 5'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 5:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 836'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 836:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2019] EWCA Crim 2280'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2019]" EWCA Crim 2280:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 1873
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 1873:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2014] EWCA Crim 1555'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2014]" EWCA Crim 1555:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2024]" EWCA Crim 88
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2024]" EWCA Crim 88:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2003] EWCA Crim 1966'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 1966:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2011] EWCA Crim 461'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2011]" EWCA Crim 461:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2015]" EWCA Crim 1328
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1328:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2006]" EWCA Crim 2570
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2006]" EWCA Crim 2570:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 1936'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1936:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2006]" EWCA Crim 400
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2006]" EWCA Crim 400:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2008] EWCA Crim 679'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 679:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2020] EWCA Crim 1266'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2020]" EWCA Crim 1266:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2005]" EWCA Crim 3692
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2005]" EWCA Crim 3692:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2005] EWCA Crim 700'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2005]" EWCA Crim 700:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2021] EWCA Crim 175'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2021]" EWCA Crim 175:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2004]" EWCA Crim 2062
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 2062:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2010]" EWCA Crim 1023
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 1023:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2003]" EWCA Crim 270
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 270:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2022] EWCA Crim 1784'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2022]" EWCA Crim 1784:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2021] EWCA Crim 268'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2021]" EWCA Crim 268:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2004] EWCA Crim 621'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 621:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2023] EWCA Crim 815'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2023]" EWCA Crim 815:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2013] EWCA Crim 1024'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2013]" EWCA Crim 1024:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2003] EWCA Crim 1008'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 1008:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 960'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 960:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2009] EWCA Crim 1915'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2009]" EWCA Crim 1915:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2010] EWCA Crim 970'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2010]" EWCA Crim 970:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2012] EWCA Crim 994'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2012]" EWCA Crim 994:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2011] EWCA Crim 73'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2011]" EWCA Crim 73:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2012]" EWCA Crim 1870
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2012]" EWCA Crim 1870:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2004]" EWCA Crim 3446
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 3446:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2004]" EWCA Crim 3156
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 3156:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2006]" EWCA Crim 2924
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2006]" EWCA Crim 2924:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2024]" EWCA Crim 231
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2024]" EWCA Crim 231:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2012]" EWCA Crim 837
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2012]" EWCA Crim 837:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2003]" EWCA Crim 3110
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2003]" EWCA Crim 3110:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 1250'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1250:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2022] EWCA Crim 1108'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2022]" EWCA Crim 1108:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2015]" EWCA Crim 1999
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 1999:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2009] EWCA Crim 880'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2009]" EWCA Crim 880:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2021] EWCA Crim 1673'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2021]" EWCA Crim 1673:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2015] EWCA Crim 2364'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2015]" EWCA Crim 2364:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2018]" EWCA Crim 835
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2018]" EWCA Crim 835:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2013]" EWCA Crim 2287
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2013]" EWCA Crim 2287:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2023] EWCA Crim 1280'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2023]" EWCA Crim 1280:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2022]" EWCA Crim 1292
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2022]" EWCA Crim 1292:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2013]" EWCA Crim 1993
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2013]" EWCA Crim 1993:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2017]" EWCA Crim 374
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2017]" EWCA Crim 374:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2008]" EWCA Crim 1455
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2008]" EWCA Crim 1455:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2011]" EWCA Crim 2587
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2011]" EWCA Crim 2587:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2009]" EWCA Crim 733
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2009]" EWCA Crim 733:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2016] EWCA Crim 1841'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2016]" EWCA Crim 1841:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2019] EWCA (Crim) 1628'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2019]" EWCA Crim 1628:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: "[2007]" EWCA Crim 2787
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2007]" EWCA Crim 2787:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2004] EWCA Crim 2901'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2004]" EWCA Crim 2901:judges
#                       ^
# Error parsing answer YAML: mapping values are not allowed here
#   in "<unicode string>", line 2, column 10:
#       Comment: '[2018] EWCA Crim 1374'
#              ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 2, column 3:
#       Comment: "nan"
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Exact: "[2018]" EWCA Crim 1374:judges
#                       ^
#
# Overall (Micro-Averaged) Metrics:
# Precision = 0.000
# Recall    = 0.000
# F1        = 0.000

# %%
import pandas as pd

# Prepare data structure for storing results per citation
results = {}

# Process each record in data
for record in data:
    answer_text = record.get("answer", "")
    gold_text = record.get("gold", "")

    # Parse YAML content from answer and gold fields
    try:
        answer_yaml = parse_yaml_content(answer_text) or {}
    except Exception as e:
        print(f"Error parsing answer YAML: {e}")
        answer_yaml = {}
    try:
        gold_yaml = parse_yaml_content(gold_text) or {}
    except Exception as e:
        print(f"Error parsing gold YAML: {e}")
        gold_yaml = {}

    # Extract citation for column grouping
    citation_number = gold_yaml.get("citation", {}).get("Exact", "Unknown Citation")

    if citation_number not in results:
        results[citation_number] = []

    for entity in ENTITY_TYPES:
        # Extract gold and predicted values for exact and comment
        gold_entity = gold_yaml.get(entity, {}) if isinstance(gold_yaml, dict) else {}
        pred_entity = answer_yaml.get(entity, {}) if isinstance(answer_yaml, dict) else {}

        gold_exact = gold_entity.get("Exact", "nan")
        gold_comment = gold_entity.get("Comment", "nan")
        pred_exact = pred_entity.get("Exact", "nan")
        pred_comment = pred_entity.get("Comment", "nan")

        # Combine exact and comment for display in a single cell
        human_combined = f"EXACT: {gold_exact}\nCOMMENT: {gold_comment}"
        ai_combined = f"EXACT: {pred_exact}\nCOMMENT: {pred_comment}"

        # Add results to the list for this citation
        results[citation_number].append({
            "Entity Type": entity,
            "Human": human_combined,
            "AI": ai_combined,
        })

# Create a DataFrame for structured evaluation output
rows = []
columns = []
for citation, entities in results.items():
    for entity_data in entities:
        entity_type = entity_data["Entity Type"]
        human_value = entity_data["Human"]
        ai_value = entity_data["AI"]

        # Initialize a row for the entity type if not already present
        if len(rows) < len(ENTITY_TYPES):
            rows.append({"Entity Type": entity_type})

        # Add human and AI data under the citation's subcolumns
        rows[ENTITY_TYPES.index(entity_type)].update({
            f"{citation} - Human": human_value,
            f"{citation} - AI": ai_value,
        })

# Convert to DataFrame and save as CSV
df_citation_eval = pd.DataFrame(rows)
output_csv_path = "data/evaluation_by_citation.csv"
df_citation_eval.to_csv(output_csv_path, index=False)

output_csv_path
# Out:
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA 849 (Crim)
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA 849 (Crim)
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 92, column 3:
#       Exact:'seventy-five were of chil ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 94, column 1:
#     VicSex:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 1528
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 1528
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2215
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2215
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2010] EWCA Crim 1949
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2010] EWCA Crim 1949
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 2674
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 2674
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 2508
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 2508
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2008] EWCA Crim 248
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2008] EWCA Crim 248
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 68, column 3:
#       Exact:'modestly paid employment  ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 70, column 1:
#     OffHomeOffence:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2012] EWCA Crim 1476
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2012] EWCA Crim 1476
#                       ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 57, column 5:
#         Comment: Mental health issue
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 58, column 38:
#      ... xact: 'a mild depressive state.'"
#                                          ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2140
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2140
#                       ^
# Error parsing answer YAML: while scanning a quoted scalar
#   in "<unicode string>", line 4, column 10:
#       Exact: 'Neutral Citation Number: [2020] ...
#              ^
# found unexpected end of stream
#   in "<unicode string>", line 4, column 13524:
#      ...  - - - - - - - - - - - - - - - -
#                                          ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 3027
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 3027
#                       ^
# Error parsing answer YAML: while scanning a quoted scalar
#   in "<unicode string>", line 19, column 12:
#       Comment: 'Breach of a SOPO, Breach of a S ...
#                ^
# found unexpected end of stream
#   in "<unicode string>", line 19, column 15913:
#      ... a SHPO, Breach of a SHPO, Breach
#                                          ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 96, column 3:
#       Exact:'she was 19'
#       ^
# could not find expected ':'
#   in "<unicode string>", line 98, column 1:
#     VicAgeOffence:
#     ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 1, column 1:
#     citation:
#     ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 129, column 2:
#      Major Bashir could not explain h ...
#      ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2014] EWCA Crim 53
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2014] EWCA Crim 53
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2005] EWCA Crim 1828
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2005] EWCA Crim 1828
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2010] EWCA Crim 700
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2010] EWCA Crim 700
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2413
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2413
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 52, column 3:
#       Exact:'such sentence to run conc ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 54, column 1:
#     WhatAncilliary:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2011] EWCA Crim 459
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2011] EWCA Crim 459
#                       ^
# Error parsing gold YAML: mapping values are not allowed here
#   in "<unicode string>", line 36, column 28:
#         Comment: Total sentence: 3 years
#                                ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 117, column 5:
#         Comment: nan
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 118, column 53:
#      ... e, who referred to there being "minimal" evidence of loss of sel ...
#                                          ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2022] EWCA Crim 1548
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2022] EWCA Crim 1548
#                       ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 63, column 5:
#         Comment: Acquainted
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 64, column 32:
#         Exact: "his stepdaughter, "C""
#                                    ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2008] EWCA Crim 1308
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2008] EWCA Crim 1308
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2016] EWCA Crim 1631
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2016] EWCA Crim 1631
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 648
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 648
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2005] EWCA Crim 3429
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2005] EWCA Crim 3429
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2003] EWCA Crim 3003
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2003] EWCA Crim 3003
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2018] EWCA Crim 1068
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2018] EWCA Crim 1068
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 876
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 876
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2014] EWCA Crim 734
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2014] EWCA Crim 734
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2010] EWCA Crim 372
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2010] EWCA Crim 372
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2003] EWCA Crim 1555
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2003] EWCA Crim 1555
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 2062
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 2062
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2006] EWCA Crim 510
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2006] EWCA Crim 510
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 1168
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 1168
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 20, column 3:
#       Exact:'seven counts of robbery a ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 22, column 1:
#     AcquitOffence:
#     ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 69, column 5:
#         Comment: 8
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 70, column 310:
#      ... ks, robbed him using the words "move away or I''ll cut you". 8.  ...
#                                          ^
# Error parsing gold YAML: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 93, column 15:
#         Comment: •	Expert report/testimony
#                   ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 1873
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 1873
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2024] EWCA Crim 88
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2024] EWCA Crim 88
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 92, column 3:
#       Exact:'six counts'
#       ^
# could not find expected ':'
#   in "<unicode string>", line 94, column 1:
#     VicSex:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2015] EWCA Crim 1328
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2015] EWCA Crim 1328
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2006] EWCA Crim 2570
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2006] EWCA Crim 2570
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2006] EWCA Crim 400
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2006] EWCA Crim 400
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2005] EWCA Crim 3692
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2005] EWCA Crim 3692
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 104, column 3:
#       Exact:'sitting on a bench'
#       ^
# could not find expected ':'
#   in "<unicode string>", line 106, column 1:
#     VicHomeOffence:
#     ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 88, column 3:
#       Exact:'someone who called hersel ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 90, column 1:
#     VicNum:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 2062
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 2062
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2010] EWCA Crim 1023
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2010] EWCA Crim 1023
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2003] EWCA Crim 270
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2003] EWCA Crim 270
#                       ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 117, column 5:
#         Comment: nan
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 118, column 59:
#      ... tion sentencing note contained "blatant lies""
#                                          ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 108, column 5:
#         Comment: Offender
#         ^
# expected <block end>, but found '<block sequence start>'
#   in "<unicode string>", line 110, column 13:
#                 - - - - - - - - - - - - - - - -  ...
#                 ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 160, column 3:
#       Exact:'section 240 of the Crimin ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 162, column 1:
#     AppealOutcome:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2012] EWCA Crim 1870
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2012] EWCA Crim 1870
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 3446
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 3446
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 3156
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 3156
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2006] EWCA Crim 2924
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2006] EWCA Crim 2924
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2024] EWCA Crim 231
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2024] EWCA Crim 231
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2012] EWCA Crim 837
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2012] EWCA Crim 837
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2003] EWCA Crim 3110
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2003] EWCA Crim 3110
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2015] EWCA Crim 1999
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2015] EWCA Crim 1999
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2018] EWCA Crim 835
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2018] EWCA Crim 835
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2013] EWCA Crim 2287
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2013] EWCA Crim 2287
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 5, column 1:
#     \n\n25.\nAs that passage makes c ...
#     ^
# could not find expected ':'
#   in "<unicode string>", line 5, column 7132:
#      ... sion of this Court in\nYaryare\n: (1) whether there was a detail ...
#                                          ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2022] EWCA Crim 1292
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2022] EWCA Crim 1292
#                       ^
# Error parsing gold YAML: while parsing a block mapping
#   in "<unicode string>", line 51, column 5:
#         Comment: unemployed
#         ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 52, column 34:
#         Exact: "street homeless and "very bad on drugs" using about £ ...
#                                      ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2013] EWCA Crim 1993
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2013] EWCA Crim 1993
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 374
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 374
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2008] EWCA Crim 1455
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2008] EWCA Crim 1455
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2011] EWCA Crim 2587
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2011] EWCA Crim 2587
#                       ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2009] EWCA Crim 733
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2009] EWCA Crim 733
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 100, column 3:
#       Exact:'six year old boy'
#       ^
# could not find expected ':'
#   in "<unicode string>", line 102, column 1:
#     VicJobOffence:
#     ^
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2787
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2787
#                       ^
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 48, column 3:
#       Exact:'six years\'' imprisonment ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 50, column 1:
#     SentenceServed:
#     ^
# 'data/evaluation_by_citation.csv'

# %%
df_citation_eval
# Out:
#                    Entity Type  \
# 0                     citation
# 1                       judges
# 2                ConvCourtName
# 3              ConvictPleaDate
# 4               ConvictOffence
# 5                AcquitOffence
# 6           ConfessPleadGuilty
# 7                    PleaPoint
# 8               RemandDecision
# 9            RemandCustodyTime
# 10               SentCourtName
# 11            SentenceReceived
# 12              SentenceServed
# 13              WhatAncilliary
# 14                      OffSex
# 15               OffAgeOffence
# 16               OffJobOffence
# 17              OffHomeOffence
# 18            OffMentalOffence
# 19             OffIntoxOffence
# 20              OffVicRelation
# 21                  VictimType
# 22                      VicNum
# 23                      VicSex
# 24               VicAgeOffence
# 25               VicJobOffence
# 26              VicHomeOffence
# 27            VicMentalOffence
# 28             VicIntoxOffence
# 29           ProsEvidTypeTrial
# 30            DefEvidTypeTrial
# 31               PreSentReport
# 32                 AggFactSent
# 33                 MitFactSent
# 34          VicImpactStatement
# 35                   Appellant
# 36                 CoDefAccNum
# 37               AppealAgainst
# 38                AppealGround
# 39              SentGuideWhich
# 40               AppealOutcome
# 41             ReasonQuashConv
# 42  ReasonSentExcessNotLenient
# 43  ReasonSentLenientNotExcess
# 44               ReasonDismiss
#
#                          [2024] EWCA Crim 474 - Human  \
# 0           EXACT: [2024] EWCA Crim 474\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE MALES'', ''MR JUSTICE H...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                             [2024] EWCA Crim 474 - AI  \
# 0   EXACT: On 24 April 2024, Before: LORD JUSTICE ...
# 1   EXACT: Before: LORD JUSTICE MALES MR JUSTICE H...
# 2   EXACT: On 18 October 2022, in the Crown Court ...
# 3   EXACT: On 18 October 2022, in the Crown Court ...
# 4   EXACT: possessing MDMA (count 2), possessing c...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: the appellant (then aged 27) pleaded gu...
# 7   EXACT: On 18 October 2022, in the Crown Court ...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 21 December 2023, he was sentenced t...
# 11  EXACT: He was sentenced to concurrent terms of...
# 12  EXACT: He was sentenced to concurrent terms of...
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: the appellant (then aged 27)\nCOMMENT: ...
# 15   EXACT: the appellant (then aged 27)\nCOMMENT: 27
# 16  EXACT: He was self-employed in his own propert...
# 17  EXACT: He stayed with his wife occasionally at...
# 18                           EXACT: nan\nCOMMENT: nan
# 19                            EXACT: nan\nCOMMENT: No
# 20  EXACT: The driver was in possession of cash an...
# 21  EXACT: The driver was in possession of cash an...
# 22  EXACT: The driver was in possession of cash an...
# 23  EXACT: The driver was in possession of cash an...
# 24                           EXACT: nan\nCOMMENT: nan
# 25  EXACT: The driver was in possession of cash an...
# 26  EXACT: The driver was in possession of cash an...
# 27                           EXACT: nan\nCOMMENT: nan
# 28                            EXACT: nan\nCOMMENT: No
# 29  EXACT: Examination of the mobile telephone sho...
# 30  EXACT: When interviewed, the appellant said th...
# 31  EXACT: A pre-sentence report said that the app...
# 32  EXACT: The judge raised the starting point for...
# 33  EXACT: A pre-sentence report said that the app...
# 34                    EXACT: nan\nCOMMENT: Don’t know
# 35            EXACT: the appellant\nCOMMENT: Offender
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: It is now argued on the appellant’s beh...
# 38  EXACT: It is now argued on the appellant’s beh...
# 39  EXACT: The judge evidently had well in mind th...
# 40  EXACT: In these circumstances, and notwithstan...
# 41                           EXACT: nan\nCOMMENT: nan
# 42  EXACT: The obstacle faced by the appellant the...
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: Nor is any complaint made about the len...
#
#                         [2014] EWCA Crim 1594 - Human  \
# 0          EXACT: [2014] EWCA Crim 1594\nCOMMENT: nan
# 1   EXACT: [''MR JUSTICE GLOBE'', ''SIR RODERICK E...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2014] EWCA Crim 1594 - AI  \
# 0   EXACT: On 12th June 2014, this court, differen...
# 1   EXACT: PRESIDENT OF THE QUEEN\'S BENCH DIVISIO...
# 2   EXACT: On 14th June 2011 in the Crown Court at...
# 3   EXACT: On 14th June 2011 in the Crown Court at...
# 4   EXACT: the applicant, Vincent Graham, pleaded ...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: the applicant, Vincent Graham, pleaded ...
# 7   EXACT: On 14th June 2011 in the Crown Court at...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10                          EXACT: nan\nCOMMENT: null
# 11                          EXACT: nan\nCOMMENT: null
# 12                           EXACT: nan\nCOMMENT: nan
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: the applicant, Vincent Graham\nCOMMENT:...
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35  EXACT: the applicant, Vincent Graham\nCOMMENT:...
# 36                           EXACT: nan\nCOMMENT: nan
# 37  EXACT: the application for leave to appeal is ...
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40  EXACT: the application for leave to appeal is ...
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44  EXACT: the application for leave to appeal is ...
#
#                          [2017] EWCA Crim 849 - Human  \
# 0           EXACT: [2017] EWCA Crim 849\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE HICKINBOTTOM'', ''MR JU...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#    [2017] EWCA Crim 849 - AI  \
# 0   EXACT: nan\nCOMMENT: nan
# 1   EXACT: nan\nCOMMENT: nan
# 2   EXACT: nan\nCOMMENT: nan
# 3   EXACT: nan\nCOMMENT: nan
# 4   EXACT: nan\nCOMMENT: nan
# 5   EXACT: nan\nCOMMENT: nan
# 6   EXACT: nan\nCOMMENT: nan
# 7   EXACT: nan\nCOMMENT: nan
# 8   EXACT: nan\nCOMMENT: nan
# 9   EXACT: nan\nCOMMENT: nan
# 10  EXACT: nan\nCOMMENT: nan
# 11  EXACT: nan\nCOMMENT: nan
# 12  EXACT: nan\nCOMMENT: nan
# 13  EXACT: nan\nCOMMENT: nan
# 14  EXACT: nan\nCOMMENT: nan
# 15  EXACT: nan\nCOMMENT: nan
# 16  EXACT: nan\nCOMMENT: nan
# 17  EXACT: nan\nCOMMENT: nan
# 18  EXACT: nan\nCOMMENT: nan
# 19  EXACT: nan\nCOMMENT: nan
# 20  EXACT: nan\nCOMMENT: nan
# 21  EXACT: nan\nCOMMENT: nan
# 22  EXACT: nan\nCOMMENT: nan
# 23  EXACT: nan\nCOMMENT: nan
# 24  EXACT: nan\nCOMMENT: nan
# 25  EXACT: nan\nCOMMENT: nan
# 26  EXACT: nan\nCOMMENT: nan
# 27  EXACT: nan\nCOMMENT: nan
# 28  EXACT: nan\nCOMMENT: nan
# 29  EXACT: nan\nCOMMENT: nan
# 30  EXACT: nan\nCOMMENT: nan
# 31  EXACT: nan\nCOMMENT: nan
# 32  EXACT: nan\nCOMMENT: nan
# 33  EXACT: nan\nCOMMENT: nan
# 34  EXACT: nan\nCOMMENT: nan
# 35  EXACT: nan\nCOMMENT: nan
# 36  EXACT: nan\nCOMMENT: nan
# 37  EXACT: nan\nCOMMENT: nan
# 38  EXACT: nan\nCOMMENT: nan
# 39  EXACT: nan\nCOMMENT: nan
# 40  EXACT: nan\nCOMMENT: nan
# 41  EXACT: nan\nCOMMENT: nan
# 42  EXACT: nan\nCOMMENT: nan
# 43  EXACT: nan\nCOMMENT: nan
# 44  EXACT: nan\nCOMMENT: nan
#
#                         [2015] EWCA Crim 1791 - Human  \
# 0          EXACT: [2015] EWCA Crim 1791\nCOMMENT: nan
# 1   EXACT: [''LADY JUSTICE RAFFERTY'', ''MR JUSTIC...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#    [2015] EWCA Crim 1791 - AI  \
# 0    EXACT: nan\nCOMMENT: nan
# 1    EXACT: nan\nCOMMENT: nan
# 2    EXACT: nan\nCOMMENT: nan
# 3    EXACT: nan\nCOMMENT: nan
# 4    EXACT: nan\nCOMMENT: nan
# 5    EXACT: nan\nCOMMENT: nan
# 6    EXACT: nan\nCOMMENT: nan
# 7    EXACT: nan\nCOMMENT: nan
# 8    EXACT: nan\nCOMMENT: nan
# 9    EXACT: nan\nCOMMENT: nan
# 10   EXACT: nan\nCOMMENT: nan
# 11   EXACT: nan\nCOMMENT: nan
# 12   EXACT: nan\nCOMMENT: nan
# 13   EXACT: nan\nCOMMENT: nan
# 14   EXACT: nan\nCOMMENT: nan
# 15   EXACT: nan\nCOMMENT: nan
# 16   EXACT: nan\nCOMMENT: nan
# 17   EXACT: nan\nCOMMENT: nan
# 18   EXACT: nan\nCOMMENT: nan
# 19   EXACT: nan\nCOMMENT: nan
# 20   EXACT: nan\nCOMMENT: nan
# 21   EXACT: nan\nCOMMENT: nan
# 22   EXACT: nan\nCOMMENT: nan
# 23   EXACT: nan\nCOMMENT: nan
# 24   EXACT: nan\nCOMMENT: nan
# 25   EXACT: nan\nCOMMENT: nan
# 26   EXACT: nan\nCOMMENT: nan
# 27   EXACT: nan\nCOMMENT: nan
# 28   EXACT: nan\nCOMMENT: nan
# 29   EXACT: nan\nCOMMENT: nan
# 30   EXACT: nan\nCOMMENT: nan
# 31   EXACT: nan\nCOMMENT: nan
# 32   EXACT: nan\nCOMMENT: nan
# 33   EXACT: nan\nCOMMENT: nan
# 34   EXACT: nan\nCOMMENT: nan
# 35   EXACT: nan\nCOMMENT: nan
# 36   EXACT: nan\nCOMMENT: nan
# 37   EXACT: nan\nCOMMENT: nan
# 38   EXACT: nan\nCOMMENT: nan
# 39   EXACT: nan\nCOMMENT: nan
# 40   EXACT: nan\nCOMMENT: nan
# 41   EXACT: nan\nCOMMENT: nan
# 42   EXACT: nan\nCOMMENT: nan
# 43   EXACT: nan\nCOMMENT: nan
# 44   EXACT: nan\nCOMMENT: nan
#
#                         [2007] EWCA Crim 3312 - Human  ...  \
# 0          EXACT: [2007] EWCA Crim 3312\nCOMMENT: nan  ...
# 1   EXACT: [''LORD JUSTICE LAWS'', ''MR JUSTICE MA...  ...
# 2                            EXACT: nan\nCOMMENT: nan  ...
# 3                            EXACT: nan\nCOMMENT: nan  ...
# 4                            EXACT: nan\nCOMMENT: nan  ...
# 5                            EXACT: nan\nCOMMENT: nan  ...
# 6                            EXACT: nan\nCOMMENT: nan  ...
# 7                            EXACT: nan\nCOMMENT: nan  ...
# 8                            EXACT: nan\nCOMMENT: nan  ...
# 9                            EXACT: nan\nCOMMENT: nan  ...
# 10                           EXACT: nan\nCOMMENT: nan  ...
# 11                           EXACT: nan\nCOMMENT: nan  ...
# 12                           EXACT: nan\nCOMMENT: nan  ...
# 13                           EXACT: nan\nCOMMENT: nan  ...
# 14                           EXACT: nan\nCOMMENT: nan  ...
# 15                           EXACT: nan\nCOMMENT: nan  ...
# 16                           EXACT: nan\nCOMMENT: nan  ...
# 17                           EXACT: nan\nCOMMENT: nan  ...
# 18                           EXACT: nan\nCOMMENT: nan  ...
# 19                           EXACT: nan\nCOMMENT: nan  ...
# 20                           EXACT: nan\nCOMMENT: nan  ...
# 21                           EXACT: nan\nCOMMENT: nan  ...
# 22                           EXACT: nan\nCOMMENT: nan  ...
# 23                           EXACT: nan\nCOMMENT: nan  ...
# 24                           EXACT: nan\nCOMMENT: nan  ...
# 25                           EXACT: nan\nCOMMENT: nan  ...
# 26                           EXACT: nan\nCOMMENT: nan  ...
# 27                           EXACT: nan\nCOMMENT: nan  ...
# 28                           EXACT: nan\nCOMMENT: nan  ...
# 29                           EXACT: nan\nCOMMENT: nan  ...
# 30                           EXACT: nan\nCOMMENT: nan  ...
# 31                           EXACT: nan\nCOMMENT: nan  ...
# 32                           EXACT: nan\nCOMMENT: nan  ...
# 33                           EXACT: nan\nCOMMENT: nan  ...
# 34                           EXACT: nan\nCOMMENT: nan  ...
# 35                           EXACT: nan\nCOMMENT: nan  ...
# 36                           EXACT: nan\nCOMMENT: nan  ...
# 37                           EXACT: nan\nCOMMENT: nan  ...
# 38                           EXACT: nan\nCOMMENT: nan  ...
# 39                           EXACT: nan\nCOMMENT: nan  ...
# 40                           EXACT: nan\nCOMMENT: nan  ...
# 41                           EXACT: nan\nCOMMENT: nan  ...
# 42                           EXACT: nan\nCOMMENT: nan  ...
# 43                           EXACT: nan\nCOMMENT: nan  ...
# 44                           EXACT: nan\nCOMMENT: nan  ...
#
#                   [2016] EWCA Crim 1841 - Human [2016] EWCA Crim 1841 - AI  \
# 0    EXACT: [2016] EWCA Crim 1841\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 1   EXACT: [''MR JUSTICE MALES'']\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 2                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 3                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 4                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 5                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 6                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 7                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 8                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 9                      EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 10                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 11                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 12                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 13                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 14                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 15                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 16                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 17                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 18                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 19                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 20                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 21                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 22                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 23                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 24                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 25                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 26                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 27                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 28                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 29                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 30                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 31                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 32                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 33                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 34                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 35                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 36                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 37                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 38                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 39                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 40                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 41                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 42                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 43                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
# 44                     EXACT: nan\nCOMMENT: nan   EXACT: nan\nCOMMENT: nan
#
#                         [2019] EWCA Crim 1628 - Human  \
# 0          EXACT: [2019] EWCA Crim 1628\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE SIMON'', ''MRS JUSTICE ...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2019] EWCA Crim 1628 - AI  \
# 0   EXACT: NCN: [2019] EWCA (Crim) 1628\nCOMMENT: ...
# 1   EXACT: B e f o r e : LORD JUSTICE SIMON MRS JU...
# 2   EXACT: On 8 March 2019 the appellant pleaded g...
# 3   EXACT: On 8 March 2019 the appellant pleaded g...
# 4   EXACT: pleaded guilty to two sexual offences i...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: On 8 March 2019 the appellant pleaded g...
# 7   EXACT: On 8 March 2019 the appellant pleaded g...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: On 8 March 2019 the appellant pleaded g...
# 11  EXACT: On 3 April he was sentenced by His Hono...
# 12  EXACT: The sentences were ordered to be served...
# 13  EXACT: A pre-sentence report recorded that the...
# 14  EXACT: The appellant was aged 20 at the date o...
# 15  EXACT: The appellant was aged 20 at the date o...
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18  EXACT: On 16 September 2018 the mother of the ...
# 19                           EXACT: nan\nCOMMENT: nan
# 20  EXACT: The messages on the download consisted ...
# 21  EXACT: The victim, JW, was 15 years old at the...
# 22  EXACT: The victim, JW, was 15 years old at the...
# 23  EXACT: The victim, JW, was 15 years old at the...
# 24  EXACT: The victim, JW, was 15 years old at the...
# 25                           EXACT: nan\nCOMMENT: nan
# 26  EXACT: On 16 September 2018 the mother of the ...
# 27  EXACT: On 16 September 2018 the mother of the ...
# 28                           EXACT: nan\nCOMMENT: nan
# 29  EXACT: The messages on the download consisted ...
# 30  EXACT: The appellant was asked about the CAWN ...
# 31  EXACT: A pre-sentence report recorded that the...
# 32  EXACT: The Judge added that there also seemed ...
# 33  EXACT: The Judge accepted that the appellant's...
# 34  EXACT: The Judge noted that the background had...
# 35  EXACT: The appellant appeals against the sente...
# 36  EXACT: The appellant was asked about the CAWN ...
# 37  EXACT: Ms Hartford-Bell submitted that the sen...
# 38  EXACT: Ms Hartford-Bell submitted that the Jud...
# 39  EXACT: The Judge referred to the Sentencing Co...
# 40  EXACT: The appeal will be allowed.\nCOMMENT: D...
# 41  EXACT: The Judge regarded it as material and s...
# 42  EXACT: The Judge added that there also seemed ...
# 43  EXACT: The Judge accepted that the appellant\'...
# 44  EXACT: The Judge referred to the Sentencing Co...
#
#                         [2007] EWCA Crim 2787 - Human  \
# 0          EXACT: [2007] EWCA Crim 2787\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE LATHAM'', ''MR JUSTICE ...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#    [2007] EWCA Crim 2787 - AI  \
# 0    EXACT: nan\nCOMMENT: nan
# 1    EXACT: nan\nCOMMENT: nan
# 2    EXACT: nan\nCOMMENT: nan
# 3    EXACT: nan\nCOMMENT: nan
# 4    EXACT: nan\nCOMMENT: nan
# 5    EXACT: nan\nCOMMENT: nan
# 6    EXACT: nan\nCOMMENT: nan
# 7    EXACT: nan\nCOMMENT: nan
# 8    EXACT: nan\nCOMMENT: nan
# 9    EXACT: nan\nCOMMENT: nan
# 10   EXACT: nan\nCOMMENT: nan
# 11   EXACT: nan\nCOMMENT: nan
# 12   EXACT: nan\nCOMMENT: nan
# 13   EXACT: nan\nCOMMENT: nan
# 14   EXACT: nan\nCOMMENT: nan
# 15   EXACT: nan\nCOMMENT: nan
# 16   EXACT: nan\nCOMMENT: nan
# 17   EXACT: nan\nCOMMENT: nan
# 18   EXACT: nan\nCOMMENT: nan
# 19   EXACT: nan\nCOMMENT: nan
# 20   EXACT: nan\nCOMMENT: nan
# 21   EXACT: nan\nCOMMENT: nan
# 22   EXACT: nan\nCOMMENT: nan
# 23   EXACT: nan\nCOMMENT: nan
# 24   EXACT: nan\nCOMMENT: nan
# 25   EXACT: nan\nCOMMENT: nan
# 26   EXACT: nan\nCOMMENT: nan
# 27   EXACT: nan\nCOMMENT: nan
# 28   EXACT: nan\nCOMMENT: nan
# 29   EXACT: nan\nCOMMENT: nan
# 30   EXACT: nan\nCOMMENT: nan
# 31   EXACT: nan\nCOMMENT: nan
# 32   EXACT: nan\nCOMMENT: nan
# 33   EXACT: nan\nCOMMENT: nan
# 34   EXACT: nan\nCOMMENT: nan
# 35   EXACT: nan\nCOMMENT: nan
# 36   EXACT: nan\nCOMMENT: nan
# 37   EXACT: nan\nCOMMENT: nan
# 38   EXACT: nan\nCOMMENT: nan
# 39   EXACT: nan\nCOMMENT: nan
# 40   EXACT: nan\nCOMMENT: nan
# 41   EXACT: nan\nCOMMENT: nan
# 42   EXACT: nan\nCOMMENT: nan
# 43   EXACT: nan\nCOMMENT: nan
# 44   EXACT: nan\nCOMMENT: nan
#
#                         [2004] EWCA Crim 2901 - Human  \
# 0          EXACT: [2004] EWCA Crim 2901\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE CLARKE'', ''MR JUSTICE ...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#    [2004] EWCA Crim 2901 - AI  \
# 0    EXACT: nan\nCOMMENT: nan
# 1    EXACT: nan\nCOMMENT: nan
# 2    EXACT: nan\nCOMMENT: nan
# 3    EXACT: nan\nCOMMENT: nan
# 4    EXACT: nan\nCOMMENT: nan
# 5    EXACT: nan\nCOMMENT: nan
# 6    EXACT: nan\nCOMMENT: nan
# 7    EXACT: nan\nCOMMENT: nan
# 8    EXACT: nan\nCOMMENT: nan
# 9    EXACT: nan\nCOMMENT: nan
# 10   EXACT: nan\nCOMMENT: nan
# 11   EXACT: nan\nCOMMENT: nan
# 12   EXACT: nan\nCOMMENT: nan
# 13   EXACT: nan\nCOMMENT: nan
# 14   EXACT: nan\nCOMMENT: nan
# 15   EXACT: nan\nCOMMENT: nan
# 16   EXACT: nan\nCOMMENT: nan
# 17   EXACT: nan\nCOMMENT: nan
# 18   EXACT: nan\nCOMMENT: nan
# 19   EXACT: nan\nCOMMENT: nan
# 20   EXACT: nan\nCOMMENT: nan
# 21   EXACT: nan\nCOMMENT: nan
# 22   EXACT: nan\nCOMMENT: nan
# 23   EXACT: nan\nCOMMENT: nan
# 24   EXACT: nan\nCOMMENT: nan
# 25   EXACT: nan\nCOMMENT: nan
# 26   EXACT: nan\nCOMMENT: nan
# 27   EXACT: nan\nCOMMENT: nan
# 28   EXACT: nan\nCOMMENT: nan
# 29   EXACT: nan\nCOMMENT: nan
# 30   EXACT: nan\nCOMMENT: nan
# 31   EXACT: nan\nCOMMENT: nan
# 32   EXACT: nan\nCOMMENT: nan
# 33   EXACT: nan\nCOMMENT: nan
# 34   EXACT: nan\nCOMMENT: nan
# 35   EXACT: nan\nCOMMENT: nan
# 36   EXACT: nan\nCOMMENT: nan
# 37   EXACT: nan\nCOMMENT: nan
# 38   EXACT: nan\nCOMMENT: nan
# 39   EXACT: nan\nCOMMENT: nan
# 40   EXACT: nan\nCOMMENT: nan
# 41   EXACT: nan\nCOMMENT: nan
# 42   EXACT: nan\nCOMMENT: nan
# 43   EXACT: nan\nCOMMENT: nan
# 44   EXACT: nan\nCOMMENT: nan
#
#                         [2018] EWCA Crim 1374 - Human  \
# 0          EXACT: [2018] EWCA Crim 1374\nCOMMENT: nan
# 1   EXACT: [''LORD JUSTICE SIMON'', ''MR JUSTICE G...
# 2                            EXACT: nan\nCOMMENT: nan
# 3                            EXACT: nan\nCOMMENT: nan
# 4                            EXACT: nan\nCOMMENT: nan
# 5                            EXACT: nan\nCOMMENT: nan
# 6                            EXACT: nan\nCOMMENT: nan
# 7                            EXACT: nan\nCOMMENT: nan
# 8                            EXACT: nan\nCOMMENT: nan
# 9                            EXACT: nan\nCOMMENT: nan
# 10                           EXACT: nan\nCOMMENT: nan
# 11                           EXACT: nan\nCOMMENT: nan
# 12                           EXACT: nan\nCOMMENT: nan
# 13                           EXACT: nan\nCOMMENT: nan
# 14                           EXACT: nan\nCOMMENT: nan
# 15                           EXACT: nan\nCOMMENT: nan
# 16                           EXACT: nan\nCOMMENT: nan
# 17                           EXACT: nan\nCOMMENT: nan
# 18                           EXACT: nan\nCOMMENT: nan
# 19                           EXACT: nan\nCOMMENT: nan
# 20                           EXACT: nan\nCOMMENT: nan
# 21                           EXACT: nan\nCOMMENT: nan
# 22                           EXACT: nan\nCOMMENT: nan
# 23                           EXACT: nan\nCOMMENT: nan
# 24                           EXACT: nan\nCOMMENT: nan
# 25                           EXACT: nan\nCOMMENT: nan
# 26                           EXACT: nan\nCOMMENT: nan
# 27                           EXACT: nan\nCOMMENT: nan
# 28                           EXACT: nan\nCOMMENT: nan
# 29                           EXACT: nan\nCOMMENT: nan
# 30                           EXACT: nan\nCOMMENT: nan
# 31                           EXACT: nan\nCOMMENT: nan
# 32                           EXACT: nan\nCOMMENT: nan
# 33                           EXACT: nan\nCOMMENT: nan
# 34                           EXACT: nan\nCOMMENT: nan
# 35                           EXACT: nan\nCOMMENT: nan
# 36                           EXACT: nan\nCOMMENT: nan
# 37                           EXACT: nan\nCOMMENT: nan
# 38                           EXACT: nan\nCOMMENT: nan
# 39                           EXACT: nan\nCOMMENT: nan
# 40                           EXACT: nan\nCOMMENT: nan
# 41                           EXACT: nan\nCOMMENT: nan
# 42                           EXACT: nan\nCOMMENT: nan
# 43                           EXACT: nan\nCOMMENT: nan
# 44                           EXACT: nan\nCOMMENT: nan
#
#                            [2018] EWCA Crim 1374 - AI
# 0   EXACT: On 22 January 2018, the appellant, Chri...
# 1   EXACT: B e f o r e : LORD JUSTICE SIMON MR JUS...
# 2   EXACT: He was sentenced in the Crown Court at ...
# 3      EXACT: On 22 January 2018\nCOMMENT: 2018-01-22
# 4   EXACT: He had pleaded guilty to drugs offences...
# 5                           EXACT: nan\nCOMMENT: null
# 6   EXACT: He had pleaded guilty to drugs offences...
# 7   EXACT: He had pleaded guilty after his further...
# 8                     EXACT: nan\nCOMMENT: Don’t know
# 9                            EXACT: nan\nCOMMENT: nan
# 10  EXACT: He was sentenced in the Crown Court at ...
# 11  EXACT: He was sentenced to imprisonment for 8 ...
# 12  EXACT: He was sentenced to 4 years' imprisonme...
# 13                          EXACT: nan\nCOMMENT: null
# 14  EXACT: The appellant, Christopher Fletcher, wh...
# 15  EXACT: The appellant, Christopher Fletcher, wh...
# 16  EXACT: The facts of these offences can be star...
# 17                    EXACT: nan\nCOMMENT: Don’t know
# 18                    EXACT: nan\nCOMMENT: Don’t know
# 19                    EXACT: nan\nCOMMENT: Don’t know
# 20                    EXACT: nan\nCOMMENT: Don’t know
# 21                          EXACT: nan\nCOMMENT: null
# 22                    EXACT: nan\nCOMMENT: Don’t know
# 23                    EXACT: nan\nCOMMENT: Don’t know
# 24                    EXACT: nan\nCOMMENT: Don’t know
# 25                    EXACT: nan\nCOMMENT: Don’t know
# 26                    EXACT: nan\nCOMMENT: Don’t know
# 27                    EXACT: nan\nCOMMENT: Don’t know
# 28                    EXACT: nan\nCOMMENT: Don’t know
# 29                          EXACT: nan\nCOMMENT: null
# 30                          EXACT: nan\nCOMMENT: null
# 31                    EXACT: nan\nCOMMENT: Don’t know
# 32  EXACT: Further, given that the second indictme...
# 33                          EXACT: nan\nCOMMENT: null
# 34                    EXACT: nan\nCOMMENT: Don’t know
# 35  EXACT: The appellant, Christopher Fletcher\nCO...
# 36                    EXACT: nan\nCOMMENT: Don’t know
# 37  EXACT: The appellant appeals with leave from t...
# 38  EXACT: No criticism is made of the consecutive...
# 39  EXACT: The guideline for supplying or offering...
# 40  EXACT: In the circumstances, we dismiss this a...
# 41                          EXACT: nan\nCOMMENT: null
# 42                          EXACT: nan\nCOMMENT: null
# 43                          EXACT: nan\nCOMMENT: null
# 44  EXACT: Having committed a similar offence in 2...
#
# [45 rows x 233 columns]
