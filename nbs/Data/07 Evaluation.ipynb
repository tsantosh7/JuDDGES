# %%
import json
import sys
import yaml
import re
# List of entity types we want to evaluate
ENTITY_TYPES = [
    "citation",
    "judges",
    "ConvCourtName",
    "ConvictPleaDate",
    "ConvictOffence",
    "AcquitOffence",
    "ConfessPleadGuilty",  # Adjusted entity name to match YAML sample
    "PleaPoint",
    "RemandDecision",
    "RemandCustodyTime",
    "SentCourtName",
    "SentenceReceived",
    "SentenceServed",
    "WhatAncilliary",
    "OffSex",
    "OffAgeOffence",
    "OffJobOffence",
    "OffHomeOffence",
    "OffMentalOffence",
    "OffIntoxOffence",
    "OffVicRelation",
    "VictimType",
    "VicNum",
    "VicSex",
    "VicAgeOffence",
    "VicJobOffence",
    "VicHomeOffence",
    "VicMentalOffence",
    "VicIntoxOffence",
    "ProsEvidTypeTrial",
    "DefEvidTypeTrial",
    "PreSentReport",
    "AggFactSent",
    "MitFactSent",
    "VicImpactStatement",
    "Appellant",
    "CoDefAccNum",
    "AppealAgainst",
    "AppealGround",
    "SentGuideWhich",
    "AppealOutcome",
    "ReasonQuashConv",
    "ReasonSentExcessNotLenient",
    "ReasonSentLenientNotExcess",
    "ReasonDismiss",
]

def is_empty(val):
    """Determine if a value is effectively empty or non-informative."""
    if val is None:
        return True
    if isinstance(val, str):
        cleaned = val.strip().lower()
        if cleaned in ["", "nan", "null", "-"]:
            return True
    return False

def compute_metrics_from_counts(tp, fp, fn):
    """Compute precision, recall, and F1 given counts of TP, FP, FN."""
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    return precision, recall, f1

def fix_single_quotes(yaml_text):
    """
    Fix single-quote issues in YAML and quote unquoted Exact values.
    """
    # Fix single-quoted strings
    pattern = re.compile(r"(^\s*[^:]+:\s*)'(.*?)'(\s*(?:\n|$))", re.MULTILINE)
    
    def replacer(match):
        prefix = match.group(1)
        content = match.group(2)
        suffix = match.group(3)
        fixed_content = content.replace("'", "''")
        return f"{prefix}'{fixed_content}'{suffix}"
    
    fixed_text = pattern.sub(replacer, yaml_text)
    
    # Wrap unquoted Exact: values in double quotes to handle problematic characters
    pattern_exact = re.compile(r"(^\s*Exact:\s*)([^\n]+)(\n|$)", re.MULTILINE)
    
    def replacer_exact(match):
        prefix = match.group(1)
        value = match.group(2)
        suffix = match.group(3)
        # If value isn't already quoted, wrap it in quotes
        if not (value.startswith('"') or value.startswith("'")):
            fixed_value = value.replace("'", "''")  # double single quotes inside value
            return f'{prefix}"{fixed_value}"{suffix}'
        else:
            return match.group(0)
    
    fixed_text = pattern_exact.sub(replacer_exact, fixed_text)
    return fixed_text

def parse_yaml_content(text):
    """
    Parse YAML from the provided text, fixing quote issues and standardizing empty values to 'nan'.
    """
    # Remove markdown fences if present
    if text.startswith("```yaml"):
        text = text.replace("```yaml", "", 1)
    if text.endswith("```"):
        text = text[:-len("```")]

    # Fix quoting issues in YAML content
    text_fixed = fix_single_quotes(text)

    # Parse the corrected YAML content
    yaml_data = yaml.safe_load(text_fixed)

    # Standardize empty or dash values to 'nan'
    def standardize_values(data):
        if isinstance(data, dict):
            return {
                key: standardize_values(value)
                for key, value in data.items()
            }
        elif isinstance(data, list):
            return [standardize_values(item) for item in data]
        elif data in ["-", ""]:
            return "nan"
        else:
            return data

    return standardize_values(yaml_data)

# %%
entity_stats = { entity: {"TP": 0, "FP": 0, "FN": 0} for entity in ENTITY_TYPES }

total_tp = total_fp = total_fn = 0

# %%
json_file_path='/home/stirunag/Downloads/sft_on_english_data/sft_on_english_data/predictions/llama_3.1_8b_instruct_fine_tuned_appealcourt_coded/outputs_42.json'

# %%
with open(json_file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

data[1]
# Out:
# {'answer': '```yaml\ncitation:\n  Comment: \'[2014] EWCA Crim 1594\'\n  Exact: \'On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious.\'\n\njudges:\n  Comment: \'PRESIDENT OF THE QUEEN\\\'S BENCH DIVISION (SIR BRIAN LEVESON), MR JUSTICE GLOBE, SIR RODERICK EVANS\'\n  Exact: \'PRESIDENT OF THE QUEEN\\\'S BENCH DIVISION: 1. On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious.\'\n\nConvCourtName:\n  Comment: \'Crown Court at Inner London, Stockport Magistrates\\\' Court\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A. The application for leave to appeal was signed "Mr Mark O\\\'Connor Henry\\\'s Solicitors" after which the address is repeated. The solicitor with conduct of the case was in Stockport Magistrates\\\' Court\'\n\nConvictPleaDate:\n  Comment: \'2011-06-14\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nConvictOffence:\n  Comment: \'Conspiracy to supply controlled drugs of Class A\'\n  Exact: \'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nAcquitOffence:\n  Comment: \'null\'\n  Exact: \'\'\n\nConfessPleadGuilty:\n  Comment: \'Yes\'\n  Exact: \'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nPleaPoint:\n  Comment: \'at first court appearance\'\n  Exact: \'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.\'\n\nRemandDecision:\n  Comment: \'Don’t know\'\n  Exact: \'\'\n\nRemandCustodyTime:\n  Comment: \'nan\'\n  Exact: \'\'\n\nSentCourtName:\n  Comment: \'null\'\n  Exact: \'\'\n\nSentenceReceived:\n  Comment: \'null\'\n  Exact: \'\'\n\nSentenceServed:\n  Comment: \'nan\'\n  Exact: \'\'\n\nWhatAncilliary:\n  Comment: \'null\'\n  Exact: \'\'\n\nOffSex:\n  Comment: \'Male\'\n  Exact: \'the applicant, Vincent Graham\'\n\nOffAgeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffJobOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffHomeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffMentalOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffIntoxOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nOffVicRelation:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVictimType:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicNum:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicSex:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicAgeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicJobOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicHomeOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicMentalOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicIntoxOffence:\n  Comment: \'nan\'\n  Exact: \'\'\n\nProsEvidTypeTrial:\n  Comment: \'nan\'\n  Exact: \'\'\n\nDefEvidTypeTrial:\n  Comment: \'nan\'\n  Exact: \'\'\n\nPreSentReport:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAggFactSent:\n  Comment: \'nan\'\n  Exact: \'\'\n\nMitFactSent:\n  Comment: \'nan\'\n  Exact: \'\'\n\nVicImpactStatement:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAppellant:\n  Comment: \'Offender\'\n  Exact: \'the applicant, Vincent Graham\'\n\nCoDefAccNum:\n  Comment: \'nan\'\n  Exact: \'\'\n\nAp ...
#  'gold': "citation:\n  Comment: nan\n  Exact: [2014] EWCA Crim 1594\njudges:\n  Comment: nan\n  Exact: ['MR JUSTICE GLOBE', 'SIR RODERICK EVANS']\n\n  ConvCourtName:\n    Comment: nan\n    Exact: Crown Court at Inner London\n  ConvictPleaDate:\n    Comment: nan\n    Exact: 14th June 2011\n  ConvictOffence:\n    Comment: nan\n    Exact: conspiracy to supply controlled drugs of Class A\n  AcquitOffence:\n    Comment: nan\n    Exact: nan\n  Confess/Plead :\n    Comment: nan\n    Exact: nan\n  PleaPoint:\n    Comment: nan\n    Exact: -\n  RemandDecision:\n    Comment: nan\n    Exact: -\n  RemandCustodyTime:\n    Comment: nan\n    Exact: -\n  SentCourtName:\n    Comment: nan\n    Exact: Crown Court at Inner London\n  Sentence:\n    Comment: nan\n    Exact: -\n  SentServe:\n    Comment: nan\n    Exact: -\n  WhatAncilliary:\n    Comment: nan\n    Exact: -\n  OffSex:\n    Comment: male\n    Exact: Vincent Graham,\n  OffAgeOffence:\n    Comment: nan\n    Exact: -\n  OffJobOffence:\n    Comment: nan\n    Exact: -\n  OffHomeOffence:\n    Comment: nan\n    Exact: -\n  OffMentalOffence:\n    Comment: nan\n    Exact: -\n  OffIntoxOffence:\n    Comment: nan\n    Exact: -\n  OffVicRelation:\n    Comment: nan\n    Exact: -\n  VictimType:\n    Comment: nan\n    Exact: -\n  VicNum:\n    Comment: nan\n    Exact: -\n  VicSex:\n    Comment: nan\n    Exact: -\n  VicAgeOffence:\n    Comment: nan\n    Exact: -\n  VicJobOffence:\n    Comment: nan\n    Exact: -\n  VicHomeOffence:\n    Comment: nan\n    Exact: -\n  VicMentalOffence:\n    Comment: nan\n    Exact: -\n  VicIntoxOffence:\n    Comment: nan\n    Exact: -\n  ProsEvidTypeTrial:\n    Comment: nan\n    Exact: -\n  DefEvidTypeTrial:\n    Comment: nan\n    Exact: -\n  PreSentReport:\n    Comment: nan\n    Exact: -\n  AggFactSent:\n    Comment: nan\n    Exact: -\n  MitFactSent:\n    Comment: nan\n    Exact: -\n  VicImpactStatement:\n    Comment: nan\n    Exact: -\n  Appellant:\n    Comment: offender\n    Exact: applicant, Vincent Graham, pleaded guilty to\n  CoDefAccNum:\n    Comment: nan\n    Exact: -\n  AppealAgainst:\n    Comment: nan\n    Exact: -\n  AppealGround:\n    Comment: nan\n    Exact: -\n  SentGuideWhich:\n    Comment: nan\n    Exact: -\n  AppealOutcome:\n    Comment: nan\n    Exact: -\n  ReasonQuashConv:\n    Comment: nan\n    Exact: -\n  ReasonSentExcessNotLenient:\n    Comment: nan\n    Exact: -\n  ReasonSentLenientNotExcess:\n    Comment: nan\n    Exact: -\n  ReasonDismiss:\n    Comment: nan\n    Exact: -\n"}

# %%
answer_text = data[1].get("answer", "")
gold_text = data[1].get("gold", "")

answer_yaml = parse_yaml_content(answer_text) or {}
gold_yaml = parse_yaml_content(gold_text) or {}

# %%
answer_yaml
# Out:
# {'citation': {'Comment': '[2014] EWCA Crim 1594',
#   'Exact': 'On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious.'},
#  'judges': {'Comment': "PRESIDENT OF THE QUEEN\\'S BENCH DIVISION (SIR BRIAN LEVESON), MR JUSTICE GLOBE, SIR RODERICK EVANS",
#   'Exact': "PRESIDENT OF THE QUEEN\\'S BENCH DIVISION: 1. On 12th June 2014, this court, differently constituted, considered a Reference by the Registrar of Criminal Appeals, pursuant to section 20 of the Criminal Appeal Act 1968, to make a summary determination whether an application for leave to appeal a confiscation order should be dismissed as frivolous or vexatious."},
#  'ConvCourtName': {'Comment': "Crown Court at Inner London, Stockport Magistrates\\' Court",
#   'Exact': 'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A. The application for leave to appeal was signed "Mr Mark O\\\'Connor Henry\\\'s Solicitors" after which the address is repeated. The solicitor with conduct of the case was in Stockport Magistrates\\\' Court'},
#  'ConvictPleaDate': {'Comment': '2011-06-14',
#   'Exact': 'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.'},
#  'ConvictOffence': {'Comment': 'Conspiracy to supply controlled drugs of Class A',
#   'Exact': 'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.'},
#  'AcquitOffence': {'Comment': 'null', 'Exact': 'nan'},
#  'ConfessPleadGuilty': {'Comment': 'Yes',
#   'Exact': 'the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.'},
#  'PleaPoint': {'Comment': 'at first court appearance',
#   'Exact': 'On 14th June 2011 in the Crown Court at Inner London before His Honour Judge Leeming QC the applicant, Vincent Graham, pleaded guilty to one count of conspiracy to supply controlled drugs of Class A.'},
#  'RemandDecision': {'Comment': 'Don’t know', 'Exact': 'nan'},
#  'RemandCustodyTime': {'Comment': 'nan', 'Exact': 'nan'},
#  'SentCourtName': {'Comment': 'null', 'Exact': 'nan'},
#  'SentenceReceived': {'Comment': 'null', 'Exact': 'nan'},
#  'SentenceServed': {'Comment': 'nan', 'Exact': 'nan'},
#  'WhatAncilliary': {'Comment': 'null', 'Exact': 'nan'},
#  'OffSex': {'Comment': 'Male', 'Exact': 'the applicant, Vincent Graham'},
#  'OffAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'OffJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'OffHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'OffMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'OffIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'OffVicRelation': {'Comment': 'nan', 'Exact': 'nan'},
#  'VictimType': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicNum': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicSex': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#  'ProsEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#  'DefEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#  'PreSentReport': {'Comment': 'nan', 'Exact': 'nan'},
#  'AggFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#  'MitFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#  'VicImpactStatement': {'Comment': 'nan', 'Exact': 'nan'},
#  'Appellant': {'Comment': 'Offender',
#   'Exact': 'the applicant, Vincent Graham'},
#  'CoDefAccNum': {'Comment': 'nan', 'Exact': 'nan'},
#  'AppealAgainst': {'Comment': 'Dismissal of application for leave to appeal',
#   'Exact': 'the application for leave to appeal is summarily dismissed.'},
#  'AppealGround': {'Comment': 'nan', 'Exact': 'nan'},
#  'SentGuideWhich': {'Comment': 'nan', 'Exact': 'nan'},
#  'AppealOutcome': {'Comment': 'Dismissed-Failed',
#   'Exact': 'the application for leave to appeal is summarily dismissed.'},
#  'ReasonQuashConv': {'Comment': 'nan', 'Exact': 'nan'},
#  'ReasonSentExcessNotLenient': {'Comment': 'nan', 'Exact': 'nan'},
#  'ReasonSentLenientNotExcess': {'Comment': 'nan', 'Exact': 'nan'},
#  'ReasonDismiss': {'Comment': 'Original sentence fell within guideline range',
#   'Exact': 'the application for leave to appeal is summarily dismissed.'}}

# %%
gold_yaml
# Out:
# {'citation': {'Comment': 'nan', 'Exact': '[2014] EWCA Crim 1594'},
#  'judges': {'Comment': 'nan',
#   'Exact': "[''MR JUSTICE GLOBE'', ''SIR RODERICK EVANS'']",
#   'ConvCourtName': {'Comment': 'nan', 'Exact': 'Crown Court at Inner London'},
#   'ConvictPleaDate': {'Comment': 'nan', 'Exact': '14th June 2011'},
#   'ConvictOffence': {'Comment': 'nan',
#    'Exact': 'conspiracy to supply controlled drugs of Class A'},
#   'AcquitOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'Confess/Plead': {'Comment': 'nan', 'Exact': 'nan'},
#   'PleaPoint': {'Comment': 'nan', 'Exact': 'nan'},
#   'RemandDecision': {'Comment': 'nan', 'Exact': 'nan'},
#   'RemandCustodyTime': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentCourtName': {'Comment': 'nan', 'Exact': 'Crown Court at Inner London'},
#   'Sentence': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentServe': {'Comment': 'nan', 'Exact': 'nan'},
#   'WhatAncilliary': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffSex': {'Comment': 'male', 'Exact': 'Vincent Graham,'},
#   'OffAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'OffVicRelation': {'Comment': 'nan', 'Exact': 'nan'},
#   'VictimType': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicNum': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicSex': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicAgeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicJobOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicHomeOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicMentalOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicIntoxOffence': {'Comment': 'nan', 'Exact': 'nan'},
#   'ProsEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#   'DefEvidTypeTrial': {'Comment': 'nan', 'Exact': 'nan'},
#   'PreSentReport': {'Comment': 'nan', 'Exact': 'nan'},
#   'AggFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#   'MitFactSent': {'Comment': 'nan', 'Exact': 'nan'},
#   'VicImpactStatement': {'Comment': 'nan', 'Exact': 'nan'},
#   'Appellant': {'Comment': 'offender',
#    'Exact': 'applicant, Vincent Graham, pleaded guilty to'},
#   'CoDefAccNum': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealAgainst': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealGround': {'Comment': 'nan', 'Exact': 'nan'},
#   'SentGuideWhich': {'Comment': 'nan', 'Exact': 'nan'},
#   'AppealOutcome': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonQuashConv': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonSentExcessNotLenient': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonSentLenientNotExcess': {'Comment': 'nan', 'Exact': 'nan'},
#   'ReasonDismiss': {'Comment': 'nan', 'Exact': 'nan'}}}

# %%
from difflib import SequenceMatcher

def similarity(a, b):
    """Compute similarity ratio between two strings."""
    return SequenceMatcher(None, a, b).ratio()

SIMILARITY_THRESHOLD = 0.5  # Adjust based on acceptable similarity level
# Out:
# Per-Entity Metrics:
#
# citation                  P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=3)
# judges                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=3)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=2, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=0, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=5, FN=0)
#
# Overall (Micro-Averaged) Metrics:
# Precision = 0.000
# Recall    = 0.000
# F1        = 0.000

# %%
# Process each record
for record in data:
    answer_text = record.get("answer", "")
    gold_text = record.get("gold", "")

    # Parse YAML content from answer and gold fields
    try:
        answer_yaml = parse_yaml_content(answer_text) or {}
    except Exception as e:
        print(f"Error parsing answer YAML: {e}")
        answer_yaml = {}
    try:
        gold_yaml = parse_yaml_content(gold_text) or {}
    except Exception as e:
        print(f"Error parsing gold YAML: {e}")
        gold_yaml = {}

    for entity in ENTITY_TYPES:
        # Extract "Comment" and "Exact" values
        gold_entity = gold_yaml.get(entity, {}) if isinstance(gold_yaml, dict) else {}
        pred_entity = answer_yaml.get(entity, {}) if isinstance(answer_yaml, dict) else {}
    
        gold_comment = gold_entity.get("Comment") if isinstance(gold_entity, dict) else None
        pred_comment = pred_entity.get("Comment") if isinstance(pred_entity, dict) else None
    
        gold_exact = gold_entity.get("Exact") if isinstance(gold_entity, dict) else None
        pred_exact = pred_entity.get("Exact") if isinstance(pred_entity, dict) else None
    
        # Initialize stats for the entity
        if entity not in entity_stats:
            entity_stats[entity] = {"TP": 0, "FP": 0, "FN": 0}
    
        # Function to update TP, FP, FN based on match
        def update_metrics(gold, pred):
            gold_present = not is_empty(gold)
            pred_present = not is_empty(pred)
            if gold_present:
                if pred_present:
                    # Check for similarity
                    if similarity(str(gold).strip(), str(pred).strip()) >= SIMILARITY_THRESHOLD:
                        entity_stats[entity]["TP"] += 1
                        return 1, 0, 0  # TP
                    else:
                        # Similarity below threshold
                        return 0, 1, 1  # FP, FN
                else:
                    # Gold present but prediction missing
                    return 0, 0, 1  # FN
            else:
                if pred_present:
                    # Prediction made but nothing in gold
                    return 0, 1, 0  # FP
                # Neither present: do nothing
                return 0, 0, 0
    
        # Update metrics for "Comment"
        tp, fp, fn = update_metrics(gold_comment, pred_comment)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
        # Update metrics for "Exact"
        tp, fp, fn = update_metrics(gold_exact, pred_exact)
        entity_stats[entity]["TP"] += tp
        entity_stats[entity]["FP"] += fp
        entity_stats[entity]["FN"] += fn
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
    # Print per-entity metrics
    print("Per-Entity Metrics:\n")
    for entity in ENTITY_TYPES:
        stats = entity_stats[entity]
        precision, recall, f1 = compute_metrics_from_counts(stats["TP"], stats["FP"], stats["FN"])
        print(f"{entity:25s} P={precision:.3f}  R={recall:.3f}  F1={f1:.3f}  (TP={stats['TP']}, FP={stats['FP']}, FN={stats['FN']})")
    
# Compute overall micro-averaged metrics
overall_precision, overall_recall, overall_f1 = compute_metrics_from_counts(total_tp, total_fp, total_fn)
print("\nOverall (Micro-Averaged) Metrics:")
print(f"Precision = {overall_precision:.3f}")
print(f"Recall    = {overall_recall:.3f}")
print(f"F1        = {overall_f1:.3f}")
# Out:
# Per-Entity Metrics:
#
# citation                  P=0.017  R=0.017  F1=0.017  (TP=2, FP=118, FN=118)
# judges                    P=0.160  R=0.155  F1=0.157  (TP=20, FP=105, FN=109)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=111, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=113, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=90, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=75, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=108, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.017  F1=0.016  (TP=2, FP=120, FN=119)
# judges                    P=0.157  R=0.154  F1=0.156  (TP=20, FP=107, FN=110)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=113, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=95, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=90, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=75, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=110, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA 849 (Crim)
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA 849 (Crim)
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=120, FN=120)
# judges                    P=0.157  R=0.153  F1=0.155  (TP=20, FP=107, FN=111)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=113, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=95, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=90, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=75, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=110, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 92, column 3:
#       Exact:'seventy-five were of chil ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 94, column 1:
#     VicSex:
#     ^
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=120, FN=121)
# judges                    P=0.157  R=0.152  F1=0.154  (TP=20, FP=107, FN=112)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=113, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=95, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=90, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=75, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=110, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=122, FN=122)
# judges                    P=0.155  R=0.150  F1=0.153  (TP=20, FP=109, FN=113)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=92, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=112, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=80, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 1528
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 1528
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=122, FN=123)
# judges                    P=0.155  R=0.149  F1=0.152  (TP=20, FP=109, FN=114)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=100, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=92, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=70, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=112, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=80, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=124, FN=124)
# judges                    P=0.153  R=0.148  F1=0.150  (TP=20, FP=111, FN=115)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=99, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=102, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=92, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=75, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=114, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=28, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=80, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.016  R=0.016  F1=0.016  (TP=2, FP=126, FN=125)
# judges                    P=0.150  R=0.147  F1=0.149  (TP=20, FP=113, FN=116)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=117, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=99, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=67, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=102, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=116, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=30, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.016  F1=0.016  (TP=2, FP=128, FN=126)
# judges                    P=0.162  R=0.159  F1=0.161  (TP=22, FP=114, FN=116)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=101, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=68, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=104, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=95, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=118, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=30, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2215
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2215
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.016  F1=0.015  (TP=2, FP=128, FN=127)
# judges                    P=0.162  R=0.158  F1=0.160  (TP=22, FP=114, FN=117)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=101, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=68, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=104, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=32, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=123, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=95, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=72, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=52, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=63, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=87, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=76, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=37, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=42, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=118, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=58, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=30, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.015  F1=0.015  (TP=2, FP=130, FN=128)
# judges                    P=0.173  R=0.170  F1=0.171  (TP=24, FP=115, FN=117)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=69, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=34, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=66, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=54, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=61, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=38, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=44, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=86, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=120, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=31, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=51, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=25, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2010] EWCA Crim 1949
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2010] EWCA Crim 1949
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.015  F1=0.015  (TP=2, FP=130, FN=129)
# judges                    P=0.173  R=0.169  F1=0.171  (TP=24, FP=115, FN=118)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=69, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=34, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=66, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=54, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=61, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=38, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=44, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=86, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=120, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=31, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=51, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=25, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2004] EWCA Crim 2674
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2004] EWCA Crim 2674
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.015  F1=0.015  (TP=2, FP=130, FN=130)
# judges                    P=0.173  R=0.168  F1=0.170  (TP=24, FP=115, FN=119)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=69, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=34, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=66, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=54, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=61, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=38, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=44, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=86, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=62, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=120, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=84, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=60, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=31, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=51, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=25, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=83, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2017] EWCA Crim 2508
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2017] EWCA Crim 2508
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.015  R=0.015  F1=0.015  (TP=2, FP=130, FN=131)
# judges                    P=0.173  R=0.167  F1=0.170  (TP=24, FP=115, FN=120)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=129, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=12, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=127, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=69, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=13, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=78, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=85, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=34, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=97, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=66, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=54, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=65, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=89, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=77, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=61, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=38, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=49, FN=0)
# ...
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=168, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=163, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=159, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=143, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=113, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=71, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=148, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=144, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=79, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=158, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=134, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=221, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=109, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=203, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=148, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=104, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=217, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=54, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=92, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=46, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=139, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.017  R=0.017  F1=0.017  (TP=4, FP=225, FN=228)
# judges                    P=0.167  R=0.160  F1=0.164  (TP=40, FP=199, FN=210)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=211, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=175, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=26, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=138, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=194, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=156, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=215, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=174, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=173, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=170, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=165, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=161, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=145, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=146, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=160, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=111, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=205, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=94, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=141, FN=0)
# Error parsing answer YAML: while parsing a block mapping
#   in "<unicode string>", line 3, column 3:
#       Comment: [2007] EWCA Crim 2787
#       ^
# expected <block end>, but found '<scalar>'
#   in "<unicode string>", line 3, column 19:
#       Comment: [2007] EWCA Crim 2787
#                       ^
# Per-Entity Metrics:
#
# citation                  P=0.017  R=0.017  F1=0.017  (TP=4, FP=225, FN=229)
# judges                    P=0.167  R=0.159  F1=0.163  (TP=40, FP=199, FN=211)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=211, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=175, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=26, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=138, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=194, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=156, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=215, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=174, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=173, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=170, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=165, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=161, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=145, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=146, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=160, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=111, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=205, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=94, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=141, FN=0)
# Error parsing answer YAML: while scanning a simple key
#   in "<unicode string>", line 48, column 3:
#       Exact:'six years\'' imprisonment ...
#       ^
# could not find expected ':'
#   in "<unicode string>", line 50, column 1:
#     SentenceServed:
#     ^
# Per-Entity Metrics:
#
# citation                  P=0.017  R=0.017  F1=0.017  (TP=4, FP=225, FN=230)
# judges                    P=0.167  R=0.159  F1=0.163  (TP=40, FP=199, FN=212)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=211, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=175, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=119, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=26, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=138, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=194, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=156, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=215, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=174, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=125, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=103, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=173, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=170, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=165, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=161, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=145, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=91, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=115, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=73, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=93, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=146, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=81, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=160, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=121, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=223, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=111, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=205, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=106, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=219, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=94, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=141, FN=0)
# Per-Entity Metrics:
#
# citation                  P=0.017  R=0.017  F1=0.017  (TP=4, FP=227, FN=231)
# judges                    P=0.166  R=0.158  F1=0.162  (TP=40, FP=201, FN=213)
# ConvCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=225, FN=0)
# ConvictPleaDate           P=0.000  R=0.000  F1=0.000  (TP=0, FP=213, FN=0)
# ConvictOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=225, FN=0)
# AcquitOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=24, FN=0)
# ConfessPleadGuilty        P=0.000  R=0.000  F1=0.000  (TP=0, FP=221, FN=0)
# PleaPoint                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=177, FN=0)
# RemandDecision            P=0.000  R=0.000  F1=0.000  (TP=0, FP=120, FN=0)
# RemandCustodyTime         P=0.000  R=0.000  F1=0.000  (TP=0, FP=26, FN=0)
# SentCourtName             P=0.000  R=0.000  F1=0.000  (TP=0, FP=140, FN=0)
# SentenceReceived          P=0.000  R=0.000  F1=0.000  (TP=0, FP=196, FN=0)
# SentenceServed            P=0.000  R=0.000  F1=0.000  (TP=0, FP=158, FN=0)
# WhatAncilliary            P=0.000  R=0.000  F1=0.000  (TP=0, FP=64, FN=0)
# OffSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=217, FN=0)
# OffAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=176, FN=0)
# OffJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=138, FN=0)
# OffHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=126, FN=0)
# OffMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=104, FN=0)
# OffIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=122, FN=0)
# OffVicRelation            P=0.000  R=0.000  F1=0.000  (TP=0, FP=174, FN=0)
# VictimType                P=0.000  R=0.000  F1=0.000  (TP=0, FP=170, FN=0)
# VicNum                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=166, FN=0)
# VicSex                    P=0.000  R=0.000  F1=0.000  (TP=0, FP=162, FN=0)
# VicAgeOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=146, FN=0)
# VicJobOffence             P=0.000  R=0.000  F1=0.000  (TP=0, FP=92, FN=0)
# VicHomeOffence            P=0.000  R=0.000  F1=0.000  (TP=0, FP=116, FN=0)
# VicMentalOffence          P=0.000  R=0.000  F1=0.000  (TP=0, FP=74, FN=0)
# VicIntoxOffence           P=0.000  R=0.000  F1=0.000  (TP=0, FP=94, FN=0)
# ProsEvidTypeTrial         P=0.000  R=0.000  F1=0.000  (TP=0, FP=150, FN=0)
# DefEvidTypeTrial          P=0.000  R=0.000  F1=0.000  (TP=0, FP=146, FN=0)
# PreSentReport             P=0.000  R=0.000  F1=0.000  (TP=0, FP=82, FN=0)
# AggFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=162, FN=0)
# MitFactSent               P=0.000  R=0.000  F1=0.000  (TP=0, FP=136, FN=0)
# VicImpactStatement        P=0.000  R=0.000  F1=0.000  (TP=0, FP=122, FN=0)
# Appellant                 P=0.000  R=0.000  F1=0.000  (TP=0, FP=225, FN=0)
# CoDefAccNum               P=0.000  R=0.000  F1=0.000  (TP=0, FP=112, FN=0)
# AppealAgainst             P=0.000  R=0.000  F1=0.000  (TP=0, FP=207, FN=0)
# AppealGround              P=0.000  R=0.000  F1=0.000  (TP=0, FP=152, FN=0)
# SentGuideWhich            P=0.000  R=0.000  F1=0.000  (TP=0, FP=108, FN=0)
# AppealOutcome             P=0.000  R=0.000  F1=0.000  (TP=0, FP=221, FN=0)
# ReasonQuashConv           P=0.000  R=0.000  F1=0.000  (TP=0, FP=56, FN=0)
# ReasonSentExcessNotLenient P=0.000  R=0.000  F1=0.000  (TP=0, FP=94, FN=0)
# ReasonSentLenientNotExcess P=0.000  R=0.000  F1=0.000  (TP=0, FP=48, FN=0)
# ReasonDismiss             P=0.000  R=0.000  F1=0.000  (TP=0, FP=143, FN=0)
#
# Overall (Micro-Averaged) Metrics:
# Precision = 0.003
# Recall    = 0.047
# F1        = 0.006

# %%
import pandas as pd

# Initialize lists to store data for the DataFrame
data = []

# Populate rows for human evaluation
for entity in ENTITY_TYPES:
    # Extract gold and predicted values
    gold_entity = gold_yaml.get(entity, {}) if isinstance(gold_yaml, dict) else {}
    pred_entity = answer_yaml.get(entity, {}) if isinstance(answer_yaml, dict) else {}

    # Extract values for 'Exact' and 'Comment'
    gold_exact = gold_entity.get("Exact", "nan")
    gold_comment = gold_entity.get("Comment", "nan")
    pred_exact = pred_entity.get("Exact", "nan")
    pred_comment = pred_entity.get("Comment", "nan")

    # Add row to the data list
    data.append({
        "Entity Type": entity,
        "Gold (Human) - Exact": gold_exact,
        "Gold (Human) - Comment": gold_comment,
        "AI - Exact": pred_exact,
        "AI - Comment": pred_comment,
    })

# Create a DataFrame
df = pd.DataFrame(data)

# Save to CSV for human evaluation
file_path = "data/human_evaluation.csv"
df.to_csv(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 32
#      30 # Save to CSV for human evaluation
#      31 file_path = "data/human_evaluation.csv"
# ---> 32 df.to_csv(file_path, index=False)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/work/github/ML4-legal-documents/ml4legal/lib/python3.10/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %%
pwd
# Out:
# '/home/stirunag/work/github/JuDDGES/nbs/Data'
